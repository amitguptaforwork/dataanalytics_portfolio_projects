# %% [markdown]
# # Table of Contents (Jupyter)
#
# • <a href="#1.0-Understanding-the-Problem-and-the-Data">1.0 Understanding the Problem and the Data</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;• <a href="#About-Task">About Task</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;• <a href="#Objective-of-this-Exercise">Objective of this Exercise</a><br>
# • <a href="#2.0-Import-and-Inspect-the-Data">2.0 Import and Inspect the Data</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;• <a href="#2.1-Preprocess-the-input-data-file-and-load-data">2.1 Preprocess the input data file and load data</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;• <a href="#2.2--Statistical-summary-for-numerical-columns-and-Unique-values-for-categorical-data">2.2  Statistical summary for numerical columns and Unique values for categorical data</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;• <a href="#2.3-Adding-insights-about-columns-and-data-size.">2.3 Adding insights about columns and data size.</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;• <a href="#2.4-Book-Review-Data-Dictionary">2.4 Book Review Data Dictionary</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;• <a href="#2.5-Missing-Values">2.5 Missing Values</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;• <a href="#2.6-Feature-Engineering---Possible-candidates-for-new-features-after-going-through-existing-columns">2.6 Feature Engineering - Possible candidates for new features after going through existing columns</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;• <a href="#2.6.1-helpfulness_ratio-and-total_ratings">2.6.1 helpfulness_ratio and total_ratings</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;• <a href="#2.6.2-reviewDate">2.6.2 reviewDate</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;• <a href="#2.6.3-reviewAge">2.6.3 reviewAge</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;• <a href="#2.6.4-bookRating">2.6.4 bookRating</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;• <a href="#2.6.5-Sentiment">2.6.5 Sentiment</a><br>
# • <a href="#3.0-Explore-Data-Characteristics">3.0 Explore Data Characteristics</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;• <a href="#3.1-Univariate-Analysis-(Analysis-of-one-attribute-at-a-time.)">3.1 Univariate Analysis (Analysis of one attribute at a time.)</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;• <a href="#Helper-functions">Helper functions</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;• <a href="#drawDetailedBoxPlot">drawDetailedBoxPlot</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;• <a href="#univariate_ordinal_analysis">univariate_ordinal_analysis</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;• <a href="#univariate_numerical_analysis">univariate_numerical_analysis</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;• <a href="#reviewerID">reviewerID</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;• <a href="#total_reviews_given">total_reviews_given</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;• <a href="#avg_helpfulness_ratio">avg_helpfulness_ratio</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;• <a href="#asin">asin</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;• <a href="#total_reviews">total_reviews</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;• <a href="#total_review_ratings">total_review_ratings</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;• <a href="#book_age">book_age</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;• <a href="#bookRating">bookRating</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;• <a href="#helpful">helpful</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;• <a href="#helpfulness_ratio">helpfulness_ratio</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;• <a href="#total_ratings">total_ratings</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;• <a href="#reviewText">reviewText</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;• <a href="#summary">summary</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;• <a href="#unixReviewTime-,-reviewDate,-review_age_days">unixReviewTime , reviewDate, review_age_days</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;• <a href="#overall">overall</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;• <a href="#3.2-Bivariate-and-Trivariate-Analysis">3.2 Bivariate and Trivariate Analysis</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;• <a href="#Helper-Functions">Helper Functions</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;• <a href="#Reusable-helper-function-for-ANOVA/KRUSKAL-to-compare-categorical-and-numerical-columns">Reusable helper function for ANOVA/KRUSKAL to compare categorical and numerical columns</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;• <a href="#Reusable-helper-function-for-chi-square-test-for-comparing-categorical-columns">Reusable helper function for chi square test for comparing categorical columns</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;• <a href="#reviewText-with-overall/sentiment">reviewText with overall/sentiment</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;• <a href="#reviewerID-vs-sentiment">reviewerID vs sentiment</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;• <a href="#helpful-versus-overall">helpful versus overall</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;• <a href="#helpful-versus-reviewText">helpful versus reviewText</a><br>
# • <a href="#4.0-Actionable-Insights-&-Recommendations">4.0 Actionable Insights & Recommendations</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;• <a href="#Summary-of-Observations">Summary of Observations</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;• <a href="#🧾-Reviewer-Insights-(`reviewerID`)">🧾 Reviewer Insights (`reviewerID`)</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;• <a href="#📚-Product-Insights-(`asin`-/-Book-Rating)">📚 Product Insights (`asin` / Book Rating)</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;• <a href="#🤝-Helpfulness-Metrics-(`helpful`)">🤝 Helpfulness Metrics (`helpful`)</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;• <a href="#✍️-Review-Content-(`reviewText`)">✍️ Review Content (`reviewText`)</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;• <a href="#⭐-Overall-Ratings-(`overall`)">⭐ Overall Ratings (`overall`)</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;• <a href="#📝-Summary-Field-(`summary`)">📝 Summary Field (`summary`)</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;• <a href="#⏰-Temporal-Insights-(`unixReviewTime`-/-`reviewDate`-/-`review_age_days`)">⏰ Temporal Insights (`unixReviewTime` / `reviewDate` / `review_age_days`)</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;• <a href="#💡-Recommendations-Based-on-EDA-Insights">💡 Recommendations Based on EDA Insights</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;• <a href="#✅-EDA-Takeaway">✅ EDA Takeaway</a><br>

# %% [markdown]
# <table>
# <th>
#
# <span style="font-size:30px; font-family:Arial;color:orange">LEGEND</span>
# </th>
# <tr><td><span style="font-size:15px; font-family:Arial;color:#e610ad;">These are insights got from analysing the data, in Pink color</span></td></tr>
# <tr><td>''' ''' code sections are notes to self, some quick code snippets, or some notes while doing analysis</td></tr>
# </table>

# %% [markdown]
# # 1.0 Understanding the Problem and the Data

# %% [markdown]
# ## About Task
#
# The following dataset contains book reviews with a score ranging from 0 to 5.
# https://drive.google.com/file/d/1tSbaP9Lj5eRjskae1OQQHzE-IiwNMz4V/view?usp=sharing
#
#
#
# ## Objective of this Exercise
#
# Implement a classifier that will predict if a review is
# *	Negative (0 <= score < 3),
# *	Mixed (3 <= score < 4),
# *	Positive (4 <= score <= 5)
# based solely on its textual content

# %% [markdown]
# # 2.0 Import and Inspect the Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import json

# %% [markdown]
# ## 2.1 Preprocess the input data file and load data
#
# The given json file is jsonl format, where we just have one json object on each line.  There is no "array"
# Following code is designed to read either a normal json or a jsonl file

# %%
def load_json_any(path: str) -> pd.DataFrame:
    """
    Loads either:
    - JSON array file
    - JSON lines (one object per line)
    Returns a pandas DataFrame.
    """
    with open(path, "r", encoding="utf-8") as f:
        first = f.read(1)
        f.seek(0)
        if first == "[":
            data = json.load(f)
            return pd.DataFrame(data)
        else:
        # json lines
            rows = [json.loads(line) for line in f if line.strip()]
            return pd.DataFrame(rows)

# %%
# Load file

df = load_json_any("reviews_train.json")
df.head()
# Out:
#        reviewerID        asin                    reviewerName   helpful  \
# 0  A1PLD0ZCFOP2E3  B00CPSNC28                       miss kate  [29, 33]
# 1  A1DSENEGGFL70O  B007Q0W62W                        mlrummel    [0, 0]
# 2  A35MPEXF4V8YAL  B00AAPGYT6  My Cozie Corner {Book Reviews}    [1, 1]
# 3  A1HRL1G1T9Q14T  B00HFD4BSW                      jwreinhold    [0, 0]
# 4  A194Q0ZZ9DNBDP  B00BBNAX34                       Mochalove    [0, 0]
#
#                                           reviewText  overall  \
# 0  It is a solid principle that the essence of dr...      2.0
# 1  I really enjoyed Little White Lies (the first ...      3.0
# 2  Andrew pens "Bloodbath Ritual", a murder myste...      4.0
# 3  This book was just as good as the first!  I lo...      5.0
# 4  This book is an excellent way to teach very yo...      5.0
#
#                                summary  unixReviewTime   reviewTime
# 0  The author should read  "The Stand"      1370217600   06 3, 2013
# ...

# %% [markdown]
# ## 2.2  Statistical summary for numerical columns and Unique values for categorical data
#
# - Instead of manually creating tables and collecting values lets automate the table creation
# - We will generate a table of all columns in Markdown format
# - We will paste this table into a markdown cell and then we may add additional analysis

# %%
#!pip install tabulate
from tabulate import tabulate
def generate_markdown_table_with_details(df):
    column_details = []
    for col in df.columns:
        #print(col)
        dtype = str(df[col].dtype)
        
        if dtype == 'object' or dtype=='category':
            cat_or_num = 'Categorical'
            #For categorical columns with list, we need to convert the list to a tuple so that we can apply unique() later
            if df[col].apply(lambda x: isinstance(x, list)).any():
                df[col] = df[col].apply(tuple)
            
            details = df[col].unique().tolist()
            if(len(details)>10):
                details = f'{df[col].nunique()} unique values. Ex. {", ".join(map(str, details[:3]))}'

        else:
            cat_or_num = 'Numerical'
            details = f"Min: {df[col].min()}, Max: {df[col].max()}"
        column_details.append([col, dtype, cat_or_num, details, ''])

    # Create a DataFrame for the table
    table_df = pd.DataFrame(column_details, columns=['Column Name', 'Data Type', 'Categorical or Numerical', 'Details', 'Business Description(fill manually)'])

    # Convert DataFrame to Markdown
    markdown_table = tabulate(table_df, headers='keys', tablefmt='pipe', showindex=False)
    return markdown_table

markdown_table = generate_markdown_table_with_details(df)
print(f'There are a total of {df.shape[0]:,} rows and {df.shape[1]} columns')
print(markdown_table)
# Out:
# There are a total of 882,619 rows and 9 columns
# ...

# %% [markdown]
# ## 2.3 Adding insights about columns and data size.
#
# - We will copy the markdown table generated above and add our inputs by analysing the columns.
# - We identify which columns are numerical, which are categorical
# - Within categorical, we identify if it is nominal or ordinal data.  This helps us to decide best graph to use
# - Also ordinal data can be converted into numeric using codes thereby making it available for some kind of graphs.

# %% [markdown]
# ## 2.4 Book Review Data Dictionary

# %% [markdown]
# There are a total of 882,619 rows and 9 columns
# | Column Name    | Data Type   | Categorical or Numerical   | Details                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 | Business Description(fill manually)   |
# |:---------------|:------------|:---------------------------|:--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:--------------------------------------|
# | reviewerID     | object      | Categorical                | 68223 unique values. Ex. A1PLD0ZCFOP2E3, A1DSENEGGFL70O, A35MPEXF4V8YAL                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |   Unique ID for the reviewer.                                    |
# | asin           | object      | Categorical                | 61934 unique values. Ex. B00CPSNC28, B007Q0W62W, B00AAPGYT6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |Amazon Standard Identification Number for the book (unique product ID).                                       |
# | reviewerName   | object      | Categorical                | 55476 unique values. Ex. miss kate, mlrummel, My Cozie Corner {Book Reviews}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |  Name of the reviewer.                                     |
# | helpful        | object      | Categorical                | 1423 unique values. Ex. (29, 33), (0, 0), (1, 1)  <br>* **Example 1: [10, 10]** Every person who rated the review found it helpful. This indicates a strongly positive perception of the review's usefulness. , <br>* **Example 2: [2, 50]** Only 2 out of 50 people found the review helpful. This suggests that the review might have missed its mark or been less informative. <br>* **Example 3: [0, 0]** No feedback was provided; the review wasn't rated, possibly indicating lack of visibility or engagement. , <br>* **Example 4: [30, 100]** 30% of the raters found the review helpful. This might indicate mixed opinions, potentially due to content relevance or clarity.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |  List of two numbers [x, y] where:<br>  x = number of people who rated the review helpful,<br>  y = total number of people who rated the review.  <br><br>**Purpose of Two Values** <br>* **Granularity of Feedback**: Having two values allows you to see not just the support for a review (how many found it helpful) but also the total engagement with the review (how many rated it at all). <br>* **Contextual Understanding**:A review marked helpful by 5 out of 5 people (e.g., [5, 5]) is potentially more impactful than one marked helpful by 100 out of 200 (e.g., [100, 200]), despite the latter having more absolute votes. <br>* **Quality vs. Quantity**: The ratio x/y  (e.g., helpfulness ratio) helps in assessing the quality of a review relative to its visibility.                                 |
# | reviewText     | object      | Categorical                | 882313 unique values. Ex. It is a solid principle that the essence of drama is conflict. |    The full text of the review.                                   |
# | overall        | int64       | Numerical                  | Min: 1, Max: 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |  Rating given by the reviewer (usually 1–5).                                     |
# | summary        | object      | Categorical                | 564895 unique values. Ex. The author should read  "The Stand", 3 stars for a reason, Must Read                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |  Short summary/title of the review.                                     |
# | unixReviewTime | int64       | Numerical                  | Min: 952214400, Max: 1406073600                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         | Time of the review in Unix timestamp format.                                      |
# | reviewTime     | object      | Categorical                | 2073 unique values. Ex. 06 3, 2013, 10 5, 2013, 06 16, 2013                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             | Human-readable date of the review (MM DD, YYYY).                                     |

# %% [markdown]
# <span style="font-size:20px; font-family:Calibri;color:#e610ad;">
# <li>The data is about book review.  Each row is a review.  We have a total of 882,619 reviews
# <li>These reviews have been provided by a total 68223 reviewers
# <li>We have a total of 61,934 book titles that have been reviewed
# <li>There is a reviewer for each review, and one reviewer may have given multiple reviews for different titles. Each review has its own row in the data
# <li>One title may have got more than one review, again, each review has its own row in the data
# <li>Each review is seen by multiple shoppers.  They may choose to rate it helpful. For each review, the total helpful ratings and total ratings are captured in the helpful column

# %% [markdown]
# ## 2.5 Missing Values
#
# Now let's check if there are any missing values in our dataset or not.

# %%
#Create a small dataframe with count of missing values, and their percentage when compared to overall data
df_analysis = pd.DataFrame(df.isnull().sum(), columns=['NumberOfMissingValues'])
df_analysis['Percentage'] = np.round(df_analysis.NumberOfMissingValues*100/len(df),6)

#Print only columns that have any missing data
df_analysis[df_analysis.NumberOfMissingValues>0]
# Out:
#               NumberOfMissingValues  Percentage
# reviewerName                   3392    0.384311

# %% [markdown]
# Let us quickly look at missing data to see if its randomly missing data, or has some reason to it.

# %%
df[df.reviewerName.isna()]
# Out:
#             reviewerID        asin reviewerName helpful  \
# 521     A2KALEV4WIZE80  B0061YAUG8          NaN  (0, 0)
# 987      A9SEWCS4CAC47  B00JMFNYP2          NaN  (0, 2)
# 1141    A111CSAB9KUP7V  B006GWO5WK          NaN  (0, 0)
# 1185    A2G75SJY01J71W  B00AMTL6V6          NaN  (0, 0)
# 1211      A9NAYMSCPYWL  B0073VIZB0          NaN  (0, 0)
# ...                ...         ...          ...     ...
# 882050  A2R8WUL3YZ86JH  B00CR77NCC          NaN  (0, 1)
# 882277  A1SALSB5S6N8GB  B00HYQJPC2          NaN  (0, 1)
# 882424   AP92OPNW68BM6  B002A4MIDQ          NaN  (0, 0)
# 882521   AYOQ39GW0PXP3  B005M2ROW8          NaN  (0, 0)
# 882564  A1YZ3M1613KIO8  B007D788ZW          NaN  (0, 0)
#
#                                                reviewText  overall  \
# 521     This is a cute short story. Its a little hot a...        3
# 987     I liked the first book with Orin and Kiria but...        5
# 1141    I liked the fact that the original Fire came w...        5
# ...

# %%
df[df.reviewerName.isna()].asin.nunique()
# Out:
# 570

# %% [markdown]
# <span style="font-size:15px; font-family:Arial;color:#e610ad;">
# <li>We have only one column, reviewerName with some missing data
# <li>Only 0.38% of data is missing
# <li>Missing data is spanning multiple years, so it seems randomly missing
# <li>While total reviews are 3392, number of reviewers is 570.
# <li>reviewerName is not a field on which we would do much analysis as far as the purpose of this study is concerned.
# <li>We can fill reviewerID in the missing fields.

# %%
# Fill missing 'reviewerName' with 'reviewerID'
df['reviewerName'] = df['reviewerName'].fillna(df['reviewerID'])

# %% [markdown]
# Lets check if we have any remaining missing values

# %%
df_analysis = pd.DataFrame(df.isnull().sum(), columns=['NumberOfMissingValues'])
df_analysis['Percentage'] = np.round(df_analysis.NumberOfMissingValues*100/len(df)).astype(int)
df_analysis
# Out:
#                 NumberOfMissingValues  Percentage
# reviewerID                          0           0
# asin                                0           0
# reviewerName                        0           0
# helpful                             0           0
# reviewText                          0           0
# overall                             0           0
# summary                             0           0
# unixReviewTime                      0           0
# reviewTime                          0           0

# %% [markdown]
# <span style="font-size:15px; font-family:Arial;color:#e610ad;">We have NO missing values</span>

# %% [markdown]
# ## 2.6 Feature Engineering - Possible candidates for new features after going through existing columns
# 1. We can create two columns out of helpful column (x,y)
#     * helpfulness_ratio: This column represents x/y , indicating the proportion of helpful votes.
#     * total_ratings: This column represents the total number of ratings (y).
# 2.  unixReviewTime can be converted into a date column.
# 3.  We can also calculate a reviewAge column, which can be the difference between reviewDate and today.  It may help us gauge how review ratings grow over time.
# 4.  We can also calculate a bookRating column, which can be a average rating for a book considering all its reviews
# 5.  We can also calculate the age of the book, which can be the max review date of entire data - review_date of the oldest review of the book . (We are assumng that the book is still in publication. If not, we can take the max_review_date for that particular book.)
# 6.  Sentiment - the exercise requires us to group overall ratings into three buckets- positive, neutral and negative

# %% [markdown]
# ### 2.6.1 helpfulness_ratio and total_ratings
# Create two columns out of helpful column (x,y)
# 1. helpfulness_ratio: This column represents x/y , indicating the proportion of helpful votes.
# 2. total_ratings: This column represents the total number of ratings (y).

# %%
# Define new column names
df['helpfulness_ratio'] = df['helpful'].apply(lambda x: x[0] / x[1] if x[1] != 0 else 0)
df['total_ratings'] = df['helpful'].apply(lambda x: x[1])

# Display the updated DataFrame
df[['helpful', 'helpfulness_ratio', 'total_ratings']].head()
# Out:
#     helpful  helpfulness_ratio  total_ratings
# 0  (29, 33)           0.878788             33
# 1    (0, 0)           0.000000              0
# 2    (1, 1)           1.000000              1
# 3    (0, 0)           0.000000              0
# 4    (0, 0)           0.000000              0

# %% [markdown]
# ### 2.6.2 reviewDate
# unixReviewTime can be converted into a date column. It will have both date and time component.

# %%
# Convert unixReviewTime to datetime
df['reviewDate'] = pd.to_datetime(df['unixReviewTime'], unit='s')

# %%
# Display the updated DataFrame
df[['unixReviewTime', 'reviewDate', 'reviewTime']].head()
# Out:
#    unixReviewTime reviewDate   reviewTime
# 0      1370217600 2013-06-03   06 3, 2013
# 1      1380931200 2013-10-05   10 5, 2013
# 2      1371340800 2013-06-16  06 16, 2013
# 3      1395705600 2014-03-25  03 25, 2014
# 4      1403913600 2014-06-28  06 28, 2014

# %% [markdown]
# ### 2.6.3 reviewAge
# We can also calculate a reviewAge column, which can be the difference between reviewDate and today.

# %%
# Calculate the max date from the reviewDate column
# Instead of using today(), its better to use max date from the data, so that the analysis does not change over time, and is based on given data.
max_date = df['reviewDate'].max()
df['review_age_days'] = (max_date - df['reviewDate']).dt.days

# %%
# Display the new column
df[['reviewDate', 'review_age_days']].head()
# Out:
#   reviewDate  review_age_days
# 0 2013-06-03              415
# 1 2013-10-05              291
# 2 2013-06-16              402
# 3 2014-03-25              120
# 4 2014-06-28               25

# %%
df.columns
# Out:
# Index(['reviewerID', 'asin', 'reviewerName', 'helpful', 'reviewText',
#        'overall', 'summary', 'unixReviewTime', 'reviewTime',
#        'helpfulness_ratio', 'total_ratings', 'reviewDate', 'review_age_days'],
#       dtype='object')

# %% [markdown]
# ### 2.6.4 bookRating
# We can also calculate a bookRating column, which can be a average rating for a book considering all its reviews

# %%
# Calculate the mean review rating for each book by first grouping by asin, then calculating mean of overall column, and then usign transform to put this value for each row of that book
df['bookRating'] = df.groupby('asin')['overall'].transform('mean')

# Display the new column
df[['asin', 'overall', 'bookRating']].head()
# Out:
#          asin  overall  bookRating
# 0  B00CPSNC28        2    3.903226
# 1  B007Q0W62W        3    3.933333
# 2  B00AAPGYT6        4    3.600000
# 3  B00HFD4BSW        5    4.855263
# 4  B00BBNAX34        5    4.800000

# %% [markdown]
# ### 2.6.5 Sentiment

# %%
def label_sentiment(score):
    if score < 3:
        return 'Negative'
    elif score < 4:
        return 'Mixed'
    else:
        return 'Positive'

df['sentiment'] = df['overall'].apply(label_sentiment)

# %% [markdown]
# # 3.0 Explore Data Characteristics

# %% [markdown]
# ## 3.1 Univariate Analysis (Analysis of one attribute at a time.)

# %% [markdown]
# ### Helper functions

# %% [markdown]
# #### drawDetailedBoxPlot
# Creating a helper function to plot a boxplot that shows detailed quartile information

# %%
def drawDetailedBoxPlot(data,ax):
    boxplot = ax.boxplot(data, vert=False, patch_artist=True)

    # Calculate the five-number summary
    min_val = np.min(data)
    q1 = np.percentile(data, 25)
    median = np.median(data)
    q3 = np.percentile(data, 75)
    max_val = np.max(data)

    iqr = q3-q1
    # Calculate outlier boundaries
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr


    arrowprops0 = dict(facecolor='black', shrink=0.05,mutation_scale=10)
    arrowprops1=dict(
                        arrowstyle='->',
                        color='black',
                        lw=1.8,           # Line width                     
                        mutation_scale=20 # Head size
                    ) 

    # Annotate the five-number summary on the boxplot


    ax.annotate(f'Min', xy=(min_val, 1), xytext=(min_val, 1.2),
                arrowprops=arrowprops1 , ha='center'  )

    ax.annotate(f'{min_val:.2f}', xy=(min_val, 1), xytext=(min_val, 0.87),ha='center')
                

    ax.annotate(f'Q1', xy=(q1, 1.07), xytext=(q1, 1.25),
                arrowprops=arrowprops1 , ha='center'  )
    ax.annotate(f'{q1:.2f}', xy=(q1, 1), xytext=(q1, 0.87),ha='center')


    ax.annotate(f'Median', xy=(median, 1.07), xytext=(median, 1.32),
                arrowprops=arrowprops1,ha='center'  )
    ax.annotate(f'{median:.2f}', xy=(median, 1), xytext=(median, 0.77),ha='center')

    ax.annotate(f'Q3', xy=(q3, 1.07), xytext=(q3, 1.25),
                arrowprops=arrowprops1 , ha='center')
    ax.annotate(f'{q3:.2f}', xy=(q3, 1), xytext=(q3, 0.87),ha='center')

    ax.annotate(f'Max', xy=(max_val, 1), xytext=(max_val, 1.2),
                arrowprops=arrowprops1 , ha='center')
    ax.annotate(f'{max_val:.2f}', xy=(max_val, 1), xytext=(max_val, 0.87),ha='center')

    # Add vertical dotted lines for outlier boundaries
    ax.axvline(lower_bound, color='red', linestyle='--', alpha=0.7, label=f'Lower Bound ({lower_bound:.1f})')
    ax.axvline(upper_bound, color='red', linestyle='--', alpha=0.7, label=f'Upper Bound ({upper_bound:.1f})')
    # Add vertical text labels along the lines
    ax.text(lower_bound, .7, 'Lower Bound', rotation=90, ha='center', va='bottom', color='black', fontsize=10)
    ax.text(upper_bound, .7, 'Upper Bound', rotation=90, ha='center', va='bottom', color='black', fontsize=10)
    return ax

# %% [markdown]
# #### univariate_ordinal_analysis
# Creating a helper function to plot multiple graphs in one figure for ordinal data

# %%
import pandas as pd
import matplotlib.pyplot as plt

def univariate_ordinal_analysis(series, column_name, order=None ):
    """
    Print summary statistics and plot distribution for an ordinal categorical Series.
    
    Parameters:
        series : pd.Series
            The ordinal categorical column.
        order : list (optional)
            Ordered list of categories (if not the Series' CategoricalDtype).
    """
    
    # Ensure categorical with order
    if not pd.api.types.is_categorical_dtype(series):
        series = series.astype("category")
    if order is not None:
        series = series.cat.set_categories(order, ordered=True)
    
    # Value counts in order
    counts = series.value_counts().reindex(series.cat.categories)
    perc = counts / counts.sum() * 100
    

    
    # Plot
    fig, ax = plt.subplots(1, 2, figsize=(10, 4))
    
    # Bar plot (counts)
    bars = counts.plot(kind="bar", ax=ax[0], color="skyblue")
    ax[0].set_title(f"{column_name} Counts by Category")
    ax[0].set_ylabel("Count")
    
    # Annotate bars with %
    for bar, pct in zip(ax[0].patches, perc):
        if not pd.isna(pct):
            ax[0].text(
                bar.get_x() + bar.get_width()/2, 
                bar.get_height(), 
                f"{pct:.1f}%", 
                ha="center", va="bottom", fontsize=9
            )
    
    # Cumulative percentage
    perc.cumsum().plot(marker="o", ax=ax[1], color="red")
    ax[1].set_title("Cumulative % by Category")
    ax[1].set_ylabel("Cumulative %")
    ax[1].set_ylim(0, 100)
    ax[1].grid(True, linestyle="--", alpha=0.5)
    
    plt.tight_layout()
    plt.show()
        # Print summary
    print(f"\n📊 Summary Statistics for {column_name}")
    print("="*50)
    print(f"Mode   : {series.mode().iloc[0]}")
    print(f"Median : {series.sort_values().iloc[len(series)//2]}")
    print("\nValue Counts (%):")
    df_analysis=pd.DataFrame({"Count": counts, "Percent": perc.round(2)})
    print(df_analysis)
    df_analysis.sort_values(by="Percent", ascending=False, inplace=True)
    print("Breakup of grades-"+", ".join([f"{idx} ({row['Percent']}%)" for idx, row in df_analysis.iterrows()]))

# %% [markdown]
# #### univariate_numerical_analysis
# Creating a helper function to plot multiple graphs and other interesting information for a numerical column

# %%
import scipy.stats as stats
import matplotlib.gridspec as gridspec
def univariate_numerical_analysis(data, column_name="Numerical Variable"):
    """
    Generate 4 key graphs for univariate analysis of numerical data
    """
    #Calculations
    mean = np.mean(data)
    q1= np.percentile(data,25)
    q2= np.percentile(data,50)
    q3= np.percentile(data,75)
    iqr = q3-q1
    # Calculate outlier boundaries
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    #Normality test
    if(len(data)>300):
        test_stat, p_value = stats.shapiro(data.sample(300))
    else:
        test_stat, p_value = stats.shapiro(data)

    # Create subplots
    fig = plt.figure(figsize=(10, 6))
    gs = gridspec.GridSpec(2, 3, figure=fig)
    fig.suptitle(f'Univariate Analysis: {column_name}', fontsize=16, fontweight='bold')
    
    # 1. Histogram with KDE
    ax1 = fig.add_subplot(gs[0, 0:2])  
    ax1.hist(data, bins=30, alpha=0.7, color='skyblue', edgecolor='black', density=True)
    # Add KDE curve
    x = np.linspace(data.min(), data.max(), 100)
    kde = stats.gaussian_kde(data)
    ax1.plot(x, kde(x), 'r-', linewidth=2, label='KDE')
    ax1.set_title('Distribution (Histogram + KDE)')
    ax1.set_xlabel(column_name)
    ax1.set_ylabel('Density')
    ax1.legend()
    ax1.grid(True, alpha=0.3)

    # Q-Q Plot (Normality Check)
    ax2 = fig.add_subplot(gs[0, 2])  
    stats.probplot(data, dist="norm", plot=ax2)
    ax2.set_title('Q-Q Plot (Normality Test)')
    ax2.grid(True, alpha=0.3)

    # Box Plot
    ax3 = fig.add_subplot(gs[1, 0:2])
    drawDetailedBoxPlot(data,ax3)
   
	# Clear the right subplot and add formatted text
    ax4 = fig.add_subplot(gs[1, 2]) 
    ax4.clear()
    ax4.set_xlim(0, 1)
    ax4.set_ylim(0, 1)
    ax4.axis('off')

    # Add title
    ax4.annotate('Summary Statistics', xy=(0.5, 0.95), 
                    ha='center', va='top', fontsize=12, fontweight='bold')

    #Find outliers
    lower_outliers =[]
    upper_outliers=[]
    for x in data:
        if x < lower_bound:
            lower_outliers.append(x)
        elif x > upper_bound:
            upper_outliers.append(x)
    outliers = lower_outliers + upper_outliers
    # Add statistics in a formatted way
    statistics = [
        ('Mean:', f"{mean:.2f}"),
        ('Std Dev:',f"{np.std(data):.2f}" ),
        ('Min Max:',f"({np.min(data):.2f}, {np.max(data):.2f})" ),
        ('25, 50, 75 Percentile:', f"{q1}, {q2:.2f}, {q3}" ),
        ('IQR:', iqr ),
        ('Outliers boundary:', f"({lower_bound},{upper_bound})" ),
        ('Outliers count:', f"({len(outliers)}), {len(outliers)*100/len(data):.1f}% of total data" ),
        ('Skewness:', f"{stats.skew(data):.2f}"),
        ('Kurtosis:', f"{stats.kurtosis(data):.2f}"),
    ]
    
    if p_value<0.05:
        statistics.append(("Distribution",f"NOT Normal. Shapiro pval {p_value:.3f}"))
    else:
        statistics.append(("Distribution",f"normal Shapiro pval {p_value}"))

    print(f"Mean value is {mean:.2f} with 50% of data lying between {q1} and {q3}")      
    if(len(outliers)>0):
        print(f"There are {len(outliers)} outliers. {len(lower_outliers)} outliers are on lower side and {len(upper_outliers)} outliers are on upper side\n")  

    y_pos = 0.85
    for label, value in statistics:
        ax4.annotate(f'{label:.<20} {value}', xy=(0.1, y_pos), 
                    ha='left', va='top', fontfamily='monospace', fontsize=8)
        y_pos -= 0.08
   
    plt.tight_layout()
    plt.show()

# %%
df.columns
# Out:
# Index(['reviewerID', 'asin', 'reviewerName', 'helpful', 'reviewText',
#        'overall', 'summary', 'unixReviewTime', 'reviewTime',
#        'helpfulness_ratio', 'total_ratings', 'reviewDate', 'review_age_days',
#        'bookRating'],
#       dtype='object')

# %% [markdown]
# ### reviewerID
#
# - Let us group data from original dataframe into a new dataframe called `df_reviewers` based on reviewer.
# - We can then use this dataframe to understand reviewer better.
# - We will find mean of helpfulness_ratio which indicates that overall, how helpful the users have found this reviewer's reviews
# - sum_total_ratings indicates the overall number of ratings that the reviews of this users have got, across all reviews. This is indicative of how engaging this reviewer is.
# - total_reviews_given simply tells how many reviews this reviewer has given.

# %%
df_reviewers = df.groupby('reviewerID', as_index=False).agg({
    'helpfulness_ratio': 'mean',
    'total_ratings': ['sum', 'count']
})
df_reviewers.columns = ['reviewerID', 'avg_helpfulness_ratio', 'sum_total_ratings', 'total_reviews_given']

# %%
reviewer_count = len(df_reviewers)
print(reviewer_count)
df_reviewers
# Out:
# 68223
#            reviewerID  avg_helpfulness_ratio  sum_total_ratings  \
# 2020   A13QTZ8CIMHHG4               0.530747               1886
# 34536  A2WZJDFX12QXKD               0.444102                792
# 37048   A320TMDV6KCFU               0.552169               1788
# 10084  A1JLU5H1CCENWX               0.432639                931
# 49124  A3PTWPKPXOG8Y5               0.467882                753
# ...               ...                    ...                ...
# 55597   AACK20B31JRTY               0.000000                  0
# 54150   A7KWRO9BS6ZQA               0.000000                  0
# 33487  A2UUYJJ4GKT921               0.000000                  0
# 3923   A17L7BTE83R6Z6               0.000000                  0
# 25991  A2FRPEQ6X9M6M3               0.000000                  1
#
#        total_reviews_given
# 2020                  1038
# 34536                  896
# 37048                  760
# 10084                  705
# 49124                  704
# ...

# %% [markdown]
# <span style="font-size:15px; font-family:Arial;color:#e610ad;">
# <li>We have 68223 reviewers

# %% [markdown]
# #### total_reviews_given
# - Let us analyse total_reviews_given by each reviewer.
# - We start by looking at what is the maximum number of reviews

# %%
df_reviewers.sort_values(by='total_reviews_given', ascending=False, inplace=True)
sns.barplot(data = df_reviewers[:20], x='reviewerID',y='total_reviews_given')
plt.hlines(y=500,xmin=-0.5, xmax=20, color='r')
plt.title("Top Reviewers")
# Out:
# Text(0.5, 1.0, 'Top Reviewers')

# %% [markdown]
# <span style="font-size:15px; font-family:Arial;color:#e610ad;">
# <li>The top reviewer has given 1000+ reviews
# <li>There are 13 reviewers with 500+ reviews

# %% [markdown]
# Now that we have a sense of maximum number of reviews, lets find average number of reviews and other characteristics of this data.

# %%
univariate_numerical_analysis(df_reviewers.total_reviews_given, "total_reviews_given Data")
# Out:
# Mean value is 12.94 with 50% of data lying between 5.0 and 12.0
# There are 7582 outliers. 0 outliers are on lower side and 7582 outliers are on upper side

# %% [markdown]
# <span style="font-size:15px; font-family:Arial;color:#e610ad;">
# <li>On average, a reviewer gives 7 reviews (using median instead of mean, as we have 7582, or more than 11% outliers.)

# %% [markdown]
# #### avg_helpfulness_ratio
#
# Let us now focus on avg_helpfulness_ratio. As mentioned earlier, this value indicates that overall, how helpful the users have found this reviewer's reviews

# %%
df_reviewers.avg_helpfulness_ratio.value_counts().sort_index()
# Out:
# avg_helpfulness_ratio
# 0.000000    7412
# 0.005263       1
# 0.005495       1
# 0.006410       1
# 0.007143       1
#             ...
# 0.993333       1
# 0.995169       1
# 0.995455       1
# 0.996169       1
# 1.000000     392
# Name: count, Length: 12019, dtype: int64

# %%
sns.displot(df_reviewers.avg_helpfulness_ratio, kde=True)
plt.title("Distribution of avg_helpfulness_ratio")
# Out:
# Text(0.5, 1.0, 'Distribution of avg_helpfulness_ratio')

# %% [markdown]
# <span style="font-size:15px; font-family:Arial;color:#e610ad;">
# <li>This diagram shows the distribution of helpfulness_ratio across reviewers.  There are many reviewers (7412) that have 0 helpfulness_ratio.  We explain the meaning of this below.

# %%
print(7412/df_reviewers.avg_helpfulness_ratio.value_counts().sort_index().sum())
print()
# Out:
# 0.10864371253096464

# %% [markdown]
# Lets view some of these 7412 reviewers

# %%
df_reviewers[df_reviewers.avg_helpfulness_ratio==0]
# Out:
#            reviewerID  avg_helpfulness_ratio  sum_total_ratings  \
# 18085  A1ZSA5QBALMJGF                    0.0                  0
# 49177  A3PXOE9PZUCD06                    0.0                  1
# 61352   ALX73Z37JY4W2                    0.0                  6
# 42892  A3DELQQODDWUI0                    0.0                  1
# 31609  A2R3V9WAW4DZK0                    0.0                  0
# ...               ...                    ...                ...
# 55597   AACK20B31JRTY                    0.0                  0
# 54150   A7KWRO9BS6ZQA                    0.0                  0
# 33487  A2UUYJJ4GKT921                    0.0                  0
# 3923   A17L7BTE83R6Z6                    0.0                  0
# 25991  A2FRPEQ6X9M6M3                    0.0                  1
#
#        total_reviews_given
# 18085                   49
# 49177                   28
# 61352                   26
# 42892                   26
# 31609                   24
# ...                    ...
# ...

# %% [markdown]
# - We can see the avg_helpfulness_ratio as zero.
# - This ratio can be zero in two scenarios
#   - No user has rated any review of this reviewer
#   - Users have rated, but nobody rated 'Helpful'. That means, all those users rated the review as 'Not helpful'.  We can see many have non zero values in sum_total_ratings.  It means there *are* people who have rated these reviews as not helpful.
#
# Lets see any one reviewer's data to get a feel.
# Lets see reviewer ALX73Z37JY4W2 who has 6 ratings given on their 26 reviews

# %%
df[df.reviewerID=='ALX73Z37JY4W2']
# Out:
#            reviewerID        asin reviewerName helpful  \
# 10434   ALX73Z37JY4W2  B00EEPZ5HA    katherine  (0, 0)
# 146118  ALX73Z37JY4W2  B00COQM3GM    katherine  (0, 0)
# 162341  ALX73Z37JY4W2  B00BEK71Q6    katherine  (0, 0)
# 202783  ALX73Z37JY4W2  B00GBL0J9E    katherine  (0, 0)
# 307286  ALX73Z37JY4W2  B00B3KPBSW    katherine  (0, 0)
# 313840  ALX73Z37JY4W2  B00KZQ2SPO    katherine  (0, 0)
# 368349  ALX73Z37JY4W2  B00GVDX692    katherine  (0, 0)
# 380522  ALX73Z37JY4W2  B00I7VVZAI    katherine  (0, 0)
# 390646  ALX73Z37JY4W2  B004SBO41S    katherine  (0, 0)
# 393846  ALX73Z37JY4W2  B00CJGUHR4    katherine  (0, 0)
# 396358  ALX73Z37JY4W2  B00JIV2YA6    katherine  (0, 0)
# 501857  ALX73Z37JY4W2  B00DPMVCIO    katherine  (0, 0)
# 515592  ALX73Z37JY4W2  B00FAH38DE    katherine  (0, 0)
# 538539  ALX73Z37JY4W2  B00E3G3HSE    katherine  (0, 2)
# 568749  ALX73Z37JY4W2  B00KKU4INA    katherine  (0, 0)
# 574417  ALX73Z37JY4W2  B00J44T4YQ    katherine  (0, 1)
# ...

# %% [markdown]
# Ok. We can see that most values are (0,0) and some are (0.1) , (0,2) etc.

# %% [markdown]
# <span style="font-size:15px; font-family:Arial;color:#e610ad;">
# <li>There are 11% reviewers (7412 reviewers out of a total 68223) that have helpfulness_ratio of 0. It means, their reviews have got NO votes that consider them helpful.

# %% [markdown]
# ### asin
# - Each book has a unique asin. So essentially asin represents a book
# - Let us group data from original dataframe into a new dataframe called `df_books` based on reviewer.
# - We can then use this dataframe to understand books better.
# - We have already calculated bookRating which indicates the average of ratings given by reviewers to this book
# - total_reviews indicates the number of reviews of this book.  It indicates engagement of reviewers.
# - total_review_ratings indicates the engagement of users other than reviewers
# - book_published_date- we guestimate book age. Assuming the book to have got its first review on the first day it was made available, we can say the oldest review is the published date !

# %%
df_books = df.groupby(['asin','bookRating'], as_index=False).agg(
    total_review_ratings=('total_ratings', 'sum'),
    total_reviews=('total_ratings', 'count'),
    book_published_date=('reviewDate', 'min'),
    latest_review_date=('reviewDate', 'max')
)
df_books
# Out:
#              asin  bookRating  total_review_ratings  total_reviews  \
# 0      B000F83SZQ    4.285714                     6              7
# 1      B000FA64PA    4.200000                     0              5
# 2      B000FA64PK    4.375000                     5              8
# 3      B000FA64QO    4.000000                     2              4
# 4      B000FBFMVG    4.333333                     6              9
# ...           ...         ...                   ...            ...
# 61929  B00LZFHL7Y    4.750000                     8             16
# 61930  B00LZKMXBI    4.800000                   229             70
# 61931  B00M029T4O    4.888889                     3              9
# 61932  B00M0RE7CS    4.962963                    83             27
# 61933  B00M13FNSS    5.000000                     7              6
#
#       book_published_date latest_review_date
# 0              2014-01-06         2014-06-10
# 1              2011-02-13         2014-01-27
# ...

# %% [markdown]
# We want to analyse the distribution of reviews a book gets over its lifetime
# We will try to get the number of reviews a book got after 1 month, 6 months and 12 months post its first review (which we are approximating as the publication date of the book)

# %%
def n_months_count(n):
    df_temp = df.copy()
    df_temp = df_temp.merge(df_books[['asin', 'bookRating', 'book_published_date']], 
                        on=['asin', 'bookRating'], how='left')

    # Calculate n month after publication
    df_temp[f'month_{n}_after_pub'] = df_temp['book_published_date'] + pd.DateOffset(months=n)

    # Filter for reviews within first month
    n_month_mask = (df_temp['reviewDate'] >= df_temp['book_published_date']) & \
                   (df_temp['reviewDate'] <= df_temp[f'month_{n}_after_pub'])

    n_month_reviews = df_temp[n_month_mask]
    # Count reviews per asin-bookRating combination
    n_month_counts = n_month_reviews.groupby(['asin', 'bookRating']).size().reset_index(name=f'reviews_after_{n}_month')
    return n_month_counts
# Merge back to df_books
n=1
month_counts = n_months_count(n)
df_books = df_books.merge(month_counts, on=['asin', 'bookRating'], how='left')
df_books[f'reviews_after_{n}_month'] = df_books[f'reviews_after_{n}_month'].fillna(0)

n=6
month_counts = n_months_count(n)
df_books = df_books.merge(month_counts, on=['asin', 'bookRating'], how='left')
df_books[f'reviews_after_{n}_month'] = df_books[f'reviews_after_{n}_month'].fillna(0)

n=12
month_counts = n_months_count(n)
df_books = df_books.merge(month_counts, on=['asin', 'bookRating'], how='left')
df_books[f'reviews_after_{n}_month'] = df_books[f'reviews_after_{n}_month'].fillna(0)

# %%
df_books
# Out:
#              asin  bookRating  total_review_ratings  total_reviews  \
# 0      B000F83SZQ    4.285714                     6              7
# 1      B000FA64PA    4.200000                     0              5
# 2      B000FA64PK    4.375000                     5              8
# 3      B000FA64QO    4.000000                     2              4
# 4      B000FBFMVG    4.333333                     6              9
# ...           ...         ...                   ...            ...
# 61929  B00LZFHL7Y    4.750000                     8             16
# 61930  B00LZKMXBI    4.800000                   229             70
# 61931  B00M029T4O    4.888889                     3              9
# 61932  B00M0RE7CS    4.962963                    83             27
# 61933  B00M13FNSS    5.000000                     7              6
#
#       book_published_date latest_review_date  reviews_after_1_month  \
# 0              2014-01-06         2014-06-10                      1
# ...

# %% [markdown]
# Convert the count of reviews to percentages- what percent of total reviews a book got in its first month, compared to overall number of reviews it ever got.

# %%
df_books.reviews_after_1_month = np.round(df_books.reviews_after_1_month*100/df_books.total_reviews)
df_books.reviews_after_6_month = np.round(df_books.reviews_after_6_month*100/df_books.total_reviews)
df_books.reviews_after_12_month = np.round(df_books.reviews_after_12_month*100/df_books.total_reviews)

# %%
df_books
# Out:
#              asin  bookRating  total_review_ratings  total_reviews  \
# 0      B000F83SZQ    4.285714                     6              7
# 1      B000FA64PA    4.200000                     0              5
# 2      B000FA64PK    4.375000                     5              8
# 3      B000FA64QO    4.000000                     2              4
# 4      B000FBFMVG    4.333333                     6              9
# ...           ...         ...                   ...            ...
# 61929  B00LZFHL7Y    4.750000                     8             16
# 61930  B00LZKMXBI    4.800000                   229             70
# 61931  B00M029T4O    4.888889                     3              9
# 61932  B00M0RE7CS    4.962963                    83             27
# 61933  B00M13FNSS    5.000000                     7              6
#
#       book_published_date latest_review_date  reviews_after_1_month  \
# 0              2014-01-06         2014-06-10                   14.0
# ...

# %% [markdown]
# Lets plot the distribution of values in the three columns

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(10, 6))
ax[0].boxplot(df_books.reviews_after_1_month)
ax[0].set_title('After 1 month')
ax[1].boxplot(df_books.reviews_after_6_month)
ax[1].set_title('After 6 months')
ax[2].boxplot(df_books.reviews_after_12_month)
ax[2].set_title('After 12 months')
plt.show()

# %%
df_books.describe()
# Out:
#          bookRating  total_review_ratings  total_reviews  \
# count  61934.000000          61934.000000   61934.000000
# mean       4.345513             19.516566      14.250961
# min        1.000000              0.000000       1.000000
# 25%        4.058824              3.000000       6.000000
# 50%        4.428571              8.000000       8.000000
# 75%        4.750000             19.000000      15.000000
# max        5.000000           4062.000000    1012.000000
# std        0.510922             48.703953      19.300134
#
#                  book_published_date             latest_review_date  \
# count                          61934                          61934
# mean   2013-03-18 16:28:13.105563904  2014-02-21 09:09:44.170245888
# min              2000-03-05 00:00:00            2009-06-15 00:00:00
# 25%              2012-09-04 00:00:00            2013-12-27 00:00:00
# 50%              2013-05-15 00:00:00            2014-05-01 00:00:00
# ...

# %% [markdown]
# On an average, a book gets 40% of the reviews it will ever get in the first month of its publication
# On an average, a book gets 86% of the reviews it will ever get in the first 6 months of its publication
# On an average, a book gets almost 100% of the reviews it will ever get in the first 12 months of its publication

# %%
df[df.asin=='B000F83SZQ']
# Out:
#             reviewerID        asin                         reviewerName  \
# 5486    A1F6404F1VG29J  B000F83SZQ                           Avidreader
# 281264  A3DE6XGZ2EPADS  B000F83SZQ                                  WPY
# 327608  A1FV0SX13TWVXQ  B000F83SZQ  Elaine H. Turley "Montana Songbird"
# 338999   A795DMNCJILA6  B000F83SZQ                                  dot
# 361824  A2HSAKHC3IBRE6  B000F83SZQ                             Wolfmist
# 570432   AN0N05A9LIJEQ  B000F83SZQ                             critters
# 807230  A1RK2OCZDSGC6R  B000F83SZQ                     ubavka seirovska
#
#        helpful                                         reviewText  overall  \
# 5486    (0, 0)  I enjoy vintage books and movies so I enjoyed ...        5
# 281264  (1, 1)  Never heard of Amy Brewster. But I don't need ...        4
# 327608  (1, 1)  I'd never read any of the Amy Brewster mysteri...        5
# 338999  (2, 2)  This was a fairly interesting read.  It had ol...        4
# ...

# %% [markdown]
# #### total_reviews
# Let us analyse total_reviews

# %%
univariate_numerical_analysis(df_books.total_reviews, "total_reviews Data")
# Out:
# Mean value is 14.25 with 50% of data lying between 6.0 and 15.0
# There are 6193 outliers. 0 outliers are on lower side and 6193 outliers are on upper side

# %%
df_books[df_books.total_reviews==1012]
# Out:
#             asin  bookRating  total_review_ratings  total_reviews  \
# 9482  B006GWO5WK    4.534585                  4062           1012
#
#      book_published_date  book_age_days
# 9482          2012-09-14            677

# %% [markdown]
# <li>On an average, a book gets 8 reviews
# <li>50% of books have 6-15 number of reviews
# <li>There is one book, ASIN = B006GWO5WK, that has 1012 reviews!

# %% [markdown]
# #### total_review_ratings
# Let us analyse total_review_ratings

# %%
print(f'Titles with reviews that have NO user rating {len(df_books[df_books.total_review_ratings==0])}')
# Out:
# Titles with reviews that have NO user rating 5344

# %% [markdown]
# <span style="font-size:15px; font-family:Arial;color:#e610ad;">
# <li>There are 61934 titles
# <li>There are 5344 titles that have reviews with no ratings.  That is, none of reviews on these titles were found to be helpful or not helpful by any user.

# %% [markdown]
# #### book_age
# Lets calculate another column called book_age from book_published_date

# %%
# Calculate the max date from the reviewDate column
# Instead of using today(), its better to use max date from the data, so that the analysis does not change over time, and is based on given data.
df_books['book_age_days'] = (max_date - df_books['book_published_date']).dt.days
df_books
# Out:
#              asin  bookRating  total_review_ratings  total_reviews  \
# 0      B000F83SZQ    4.285714                     6              7
# 1      B000FA64PA    4.200000                     0              5
# 2      B000FA64PK    4.375000                     5              8
# 3      B000FA64QO    4.000000                     2              4
# 4      B000FBFMVG    4.333333                     6              9
# ...           ...         ...                   ...            ...
# 61929  B00LZFHL7Y    4.750000                     8             16
# 61930  B00LZKMXBI    4.800000                   229             70
# 61931  B00M029T4O    4.888889                     3              9
# 61932  B00M0RE7CS    4.962963                    83             27
# 61933  B00M13FNSS    5.000000                     7              6
#
#       book_published_date  book_age_days
# 0              2014-01-06            198
# 1              2011-02-13           1256
# ...

# %%
sns.scatterplot(x='book_age_days', y='total_reviews', data=df_books)
# Out:
# <Axes: xlabel='book_age_days', ylabel='total_reviews'>

# %% [markdown]
# <span style="font-size:15px; font-family:Arial;color:#e610ad;">
# <li>Books that are less than 2000 days old (~5.5yrs) have more reviews compared to those older than that.  As the latest review in the data is from 2014, it means books from 2008 onwards have more reviews compard to those before 2008

# %% [markdown]
# #### bookRating
# Let us now analyse bookRating

# %%
sns.displot(df_books.bookRating, kde=True)
plt.title("Distribution of Book Rating")
# Out:
# Text(0.5, 1.0, 'Distribution of Book Rating')

# %% [markdown]
# <span style="font-size:15px; font-family:Arial;color:#e610ad;">
#
# - So we have a skewed distribution.
# - The rating distribution indicates people tend to give good ratings more than they tend to give bad ratings (it is not wrong to assume that we have bad books and we have good books.)
# - Let us ponder on why people leave reviews
# - Positive Review Bias:
#     - Confirmation Bias: People might leave positive reviews to confirm their positive initial expectations.
#     - Social Influence: Writing a positive review can be influenced by wanting to belong to a group that appreciates quality content.
#
# - Negative Review Hesitation:
#     - Cognitive Dissonance: Buyers might avoid leaving a negative review to reduce the discomfort of a purchase they regret.
#     - Fear of Judgment: Some may fear judgment for admitting they bought a "bad" book, especially if it was popular or highly rated.
#
# - Motives to Leave Reviews:
#     - Altruism: Positive reviews are often motivated by the desire to support others in making good purchase decisions.
#     - Personal Validation: Writing a review can serve as a way to validate one’s judgment and feelings about a book.

# %% [markdown]
# Lets bin the values to understand the distribution even better.

# %%
# Calculate histogram bins and counts
counts, bins = np.histogram(df_books['bookRating'], bins=4)
bookCount = len(df_books)

# Plot the histogram
plt.hist(df_books['bookRating'], bins=bins, edgecolor='black')
plt.title("Distribution of Book Rating Binned")
plt.xlabel("Book Rating")
plt.ylabel("Frequency")

# Print counts for each bin
for i in range(len(bins) - 1):
    print(f"Bin {bins[i]:.2f} - {bins[i+1]:.2f}: {counts[i]} values {counts[i]*100/bookCount:.1f}% ")

plt.show()
# Out:
# Bin 1.00 - 2.00: 78 values 0.1%
# Bin 2.00 - 3.00: 874 values 1.4%
# Bin 3.00 - 4.00: 10655 values 17.2%
# Bin 4.00 - 5.00: 50327 values 81.3%

# %% [markdown]
# <span style="font-size:15px; font-family:Arial;color:#e610ad;">
# <li>81% of books have POSITIVE rating (rating 4-5)
# <li>17.2% of books have MIXED rating (rating 3-4)
# <li>1.5% of books have NEGATIVE rating (rating 0-3)

# %%
df_books.columns
# Out:
# Index(['asin', 'bookRating', 'total_review_ratings', 'total_reviews',
#        'book_published_date', 'book_age_days'],
#       dtype='object')

# %%
books_per_month = df_books.groupby(df_books['book_published_date'].dt.to_period('M')).size()
books_per_month.plot(kind='line', title='Books published Over Time')
# Out:
# <Axes: title={'center': 'Books published Over Time'}, xlabel='book_published_date'>

# %% [markdown]
# We are assuming that the first review of the book is close to its published date.  Given that, we can see a surge in number of books published since 2011

# %%
df_books['month'] = df_books['book_published_date'].dt.month
monthly_pattern = df_books.groupby('month').size()
monthly_pattern.plot(kind='bar', title='Books published by Month')
# Out:
# <Axes: title={'center': 'Books published by Month'}, xlabel='month'>

# %% [markdown]
# Maximum number of books are published in March, and least in August

# %%
df.columns
# Out:
# Index(['reviewerID', 'asin', 'reviewerName', 'helpful', 'reviewText',
#        'overall', 'summary', 'unixReviewTime', 'reviewTime',
#        'helpfulness_ratio', 'total_ratings', 'reviewDate', 'review_age_days',
#        'bookRating'],
#       dtype='object')

# %% [markdown]
# ### helpful

# %%
df.helpful.value_counts()
# Out:
# helpful
# (0, 0)      476337
# (1, 1)      170729
# (2, 2)       49235
# (0, 1)       33817
# (1, 2)       28098
#              ...
# (7, 35)          1
# (3, 23)          1
# (43, 50)         1
# (83, 93)         1
# (20, 40)         1
# Name: count, Length: 1423, dtype: int64

# %%
totalReviews = len(df)
476337*100/totalReviews
# Out:
# 53.96858667216545

# %% [markdown]
# <span style="font-size:15px; font-family:Arial;color:#e610ad;">
# <li>476337 reviews out of 882619 or 54% of reviews have NO user ratings.

# %% [markdown]
# ### helpfulness_ratio
# - We calculated this column from helpful column only.
# - It is a ratio of total helpful ratings/ total ratings
# - Let us analyse it.

# %%
univariate_numerical_analysis(df.helpfulness_ratio, "helpfulness_ratio Data")
# Out:
# Mean value is 0.37 with 50% of data lying between 0.0 and 1.0

# %%
df_analysis = df.helpfulness_ratio.value_counts().reset_index().sort_values(by= 'count',ascending=False)

# %%
df_analysis['percent'] = np.round(df_analysis['count']*100/totalReviews,1)
df_analysis
# Out:
#      helpfulness_ratio   count  percent
# 0             0.000000  516984     58.6
# 1             1.000000  272076     30.8
# 2             0.500000   32505      3.7
# 3             0.666667   15274      1.7
# 4             0.750000    8729      1.0
# ..                 ...     ...      ...
# 593           0.896226       1      0.0
# 592           0.940299       1      0.0
# 591           0.961783       1      0.0
# 590           0.468750       1      0.0
# 874           0.346154       1      0.0
#
# [875 rows x 3 columns]

# %%
516984 - 476337
# Out:
# 40647

# %% [markdown]
# <span style="font-size:15px; font-family:Arial;color:#e610ad;">
# <li>We earlier found that 476337 reviews out of 882619 or 54% of reviews have NO user ratings.
# <li>However there are reviews which have user ratings, but none are helpful. The count of such reviews is 40647.  So overall we have 58.6% of reviews that have a helpfulness_Ratio of ZERO.  And out of this 58.6%, 54% are reviews that have no rating, and 4.6% are reviews that were rated not useful.
# <li> This also means that 100-58.6 = 41.4% of reviews have some usefulness to the users as users have given atleast 1 helpful rating to such reviews.
# <li>272,076 or 30.8% of reviews have a helpfulness rating of 1.  This is very good figure. It means almost 31% of reviews are found to be very very useful by the users and they have thus rated these reviews as helpful.

# %% [markdown]
# ### total_ratings
# - We calculated this column from helpful column only.
# - It is the total ratings part from helpful tuple.
# - Let us analyse it.

# %%
df.columns
# Out:
# Index(['reviewerID', 'asin', 'reviewerName', 'helpful', 'reviewText',
#        'overall', 'summary', 'unixReviewTime', 'reviewTime',
#        'helpfulness_ratio', 'total_ratings', 'reviewDate', 'review_age_days',
#        'bookRating'],
#       dtype='object')

# %%
univariate_numerical_analysis(df.total_ratings, "total_ratings Data")
# Out:
# Mean value is 1.37 with 50% of data lying between 0.0 and 1.0
# There are 119689 outliers. 0 outliers are on lower side and 119689 outliers are on upper side

# %%
df.total_ratings.value_counts()
# Out:
# total_ratings
# 0       476337
# 1       204546
# 2        82047
# 3        39406
# 4        23269
#          ...
# 161          1
# 291          1
# 428          1
# 1575         1
# 240          1
# Name: count, Length: 207, dtype: int64

# %%
df[df.total_ratings==2537]
# Out:
#             reviewerID        asin       reviewerName       helpful  \
# 722701  A10PEXB6XAQ5XF  B006GWO5WK  Michael Gallagher  (2350, 2537)
#
#                                                reviewText  overall  \
# 722701  Sure, Amazon should have included one of these...        4
#
#                                                  summary  unixReviewTime  \
# 722701  Solid Charger and Necessary for Your Kindle Fire      1349740800
#
#         reviewTime  helpfulness_ratio  total_ratings reviewDate  \
# 722701  10 9, 2012           0.926291           2537 2012-10-09
#
#         review_age_days  bookRating
# 722701              652    4.534585

# %% [markdown]
# <span style="font-size:15px; font-family:Arial;color:#e610ad;">
# <li>This reconfirms the value of 476337 that we got while analysing helpfulness_ratio. These are the number of reviews that have NO user rating.  Its 54% of the data.
# <li>The review of B006GWO5WK ASIN by reviewer A10PEXB6XAQ5XF Michael Gallagher has 2537 ratings and 2350 users found this review to be helpful!!

# %%
df.columns
# Out:
# Index(['reviewerID', 'asin', 'reviewerName', 'helpful', 'reviewText',
#        'overall', 'summary', 'unixReviewTime', 'reviewTime',
#        'helpfulness_ratio', 'total_ratings', 'reviewDate', 'review_age_days',
#        'bookRating'],
#       dtype='object')

# %% [markdown]
# ### reviewText

# %%
df_review = df[['reviewText','overall','summary','helpfulness_ratio','sentiment']].copy()
df_review
# Out:
#                                                reviewText  overall  \
# 0       It is a solid principle that the essence of dr...        2
# 1       I really enjoyed Little White Lies (the first ...        3
# 2       Andrew pens "Bloodbath Ritual", a murder myste...        4
# 3       This book was just as good as the first!  I lo...        5
# 4       This book is an excellent way to teach very yo...        5
# ...                                                   ...      ...
# 882614  When I began this series, I was amazed at the ...        5
# 882615  Eve MacMillan, scientist and woman in love, ha...        5
# 882616  I read a few book by this author some good som...        4
# 882617  If I could give this book a six stars I would....        5
# 882618  I was given an advance copy of this book to re...        5
#
#                                                 summary  helpfulness_ratio  \
# 0                   The author should read  "The Stand"           0.878788
# ...

# %%
# Add length column (character count)
df_review['text_length'] = df_review['reviewText'].str.len()

# Add word count column
df_review['word_count'] = df_review['reviewText'].str.split().str.len()
df_review
# Out:
#                                                reviewText  overall  \
# 0       It is a solid principle that the essence of dr...        2
# 1       I really enjoyed Little White Lies (the first ...        3
# 2       Andrew pens "Bloodbath Ritual", a murder myste...        4
# 3       This book was just as good as the first!  I lo...        5
# 4       This book is an excellent way to teach very yo...        5
# ...                                                   ...      ...
# 882614  When I began this series, I was amazed at the ...        5
# 882615  Eve MacMillan, scientist and woman in love, ha...        5
# 882616  I read a few book by this author some good som...        4
# 882617  If I could give this book a six stars I would....        5
# 882618  I was given an advance copy of this book to re...        5
#
#                                                 summary  helpfulness_ratio  \
# 0                   The author should read  "The Stand"           0.878788
# ...

# %%
df_review.describe()
# Out:
#          text_length     word_count
# count  882619.000000  882619.000000
# mean      604.021329     109.916857
# std       731.835165     130.884756
# min         0.000000       0.000000
# 25%       176.000000      33.000000
# 50%       332.000000      62.000000
# 75%       714.000000     130.000000
# max     23037.000000    4385.000000

# %%
univariate_numerical_analysis(df_review.text_length, "text_length Data")
# Out:
# Mean value is 604.02 with 50% of data lying between 176.0 and 714.0
# There are 80980 outliers. 0 outliers are on lower side and 80980 outliers are on upper side

# %% [markdown]
# <span style="font-size:15px; font-family:Arial;color:#e610ad;">
# <li>50% of review are between 176 and 714 characters
# 91% of reviews are below 1521 characters
# There is one review that is 23,037 characters long

# %%
univariate_numerical_analysis(df_review.word_count, "word_count Data")
# Out:
# Mean value is 109.92 with 50% of data lying between 33.0 and 130.0
# There are 80324 outliers. 0 outliers are on lower side and 80324 outliers are on upper side

# %% [markdown]
# <span style="font-size:15px; font-family:Arial;color:#e610ad;">
# <li>50% of review are between 33 and 130 words
# <li>91% of reviews are below 275 words
# <li>There is one review that is 4385 words long

# %%
# !pip install langdetect
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached langdetect-1.0.9-py3-none-any.whl
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import re
import pandas as pd
import html
from collections import Counter
from langdetect import detect, DetectorFactory
DetectorFactory.seed = 42  # for reproducible language results


def analyze_text_quality(df: pd.DataFrame, text_col="reviewText", sample_size=500):
    """
    Analyze text cleanliness indicators for reviewText or another text column.

    Parameters
    ----------
    df : pd.DataFrame
        DataFrame containing a text column.
    text_col : str
        Name of the column with the raw text.
    sample_size : int
        Number of rows to sample for the analysis.

    Returns
    -------
    dict
        Summary statistics describing what kinds of content the text contains.
    """

    # Regular expressions for simple pattern checks
    html_pattern = re.compile(r"<[^>]+>")
    url_pattern = re.compile(r"http[s]?://|www\.")
    emoji_pattern = re.compile(
        "[\U0001F600-\U0001F64F"  # emoticons
        "\U0001F300-\U0001F5FF"   # symbols & pictographs
        "\U0001F680-\U0001F6FF"   # transport & map
        "\U0001F1E0-\U0001F1FF"   # flags (iOS)
        "]+", flags=re.UNICODE
    )

    # Sample subset for inspection (avoid scanning huge dataset)
    sample = df[text_col].dropna().astype(str)
    if len(sample) > sample_size:
        sample = sample.sample(sample_size, random_state=42)

    n = len(sample)
    stats = Counter()
    length_list = []
    alpha_ratio_list = []
    lang_counter = Counter()

    for txt in sample:
        txt_unescaped = html.unescape(txt)
        length_list.append(len(txt_unescaped))
        alpha_ratio_list.append(sum(c.isalpha() for c in txt_unescaped) / (len(txt_unescaped) + 1e-6))

        if html_pattern.search(txt_unescaped):
            stats["has_html"] += 1
        if url_pattern.search(txt_unescaped):
            stats["has_url"] += 1
        if emoji_pattern.search(txt_unescaped):
            stats["has_emoji"] += 1

        # Detect language (try/except to avoid crashes on mixed or empty texts)
        try:
            lang = detect(txt_unescaped)
        except Exception:
            lang = "unknown"
        lang_counter[lang] += 1

    # Summaries
    summary = {
        "n_analyzed": n,
        "pct_with_html": 100 * stats["has_html"] / n,
        "pct_with_url": 100 * stats["has_url"] / n,
        "pct_with_emoji": 100 * stats["has_emoji"] / n,
        "avg_length": sum(length_list) / n,
        "avg_alpha_ratio": sum(alpha_ratio_list) / n,
        "language_distribution": dict(lang_counter.most_common(10)),
    }

    print("---- Text Quality Report ----")
    for k, v in summary.items():
        print(f"{k}: {v}")

    return summary

# %%
#summaryReviewText = analyze_text_quality(df, text_col="reviewText", sample_size=50000)
# Out:
# ---- Text Quality Report ----
# n_analyzed: 50000
# pct_with_html: 0.102
# pct_with_url: 0.116
# pct_with_emoji: 0.06
# avg_length: 598.01626
# avg_alpha_ratio: 0.7846516820471483
# language_distribution: {'en': 49945, 'de': 31, 'es': 7, 'af': 6, 'no': 2, 'so': 2, 'tl': 2, 'fr': 1, 'ro': 1, 'unknown': 1}

# %%
49945*100/50000
# Out:
# 99.89

# %% [markdown]
# <span style="font-size:15px; font-family:Arial;color:#e610ad;">
# <li>99.89% of the reviews are in English.
# <li>0.1% reviews have html tags
# <li>0.1% reviews have urls

# %% [markdown]
# ### summary

# %%
df_analysis = df[['summary']]
# Add length column (character count)
df_analysis['text_length'] = df_analysis['summary'].str.len()

# Add word count column
df_analysis['word_count'] = df_analysis['summary'].str.split().str.len()
df_analysis
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_33312\1946311537.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_analysis['text_length'] = df_analysis['summary'].str.len()
# C:\Users\Admin\AppData\Local\Temp\ipykernel_33312\1946311537.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_analysis['word_count'] = df_analysis['summary'].str.split().str.len()
#                                                 summary  text_length  \
# ...

# %%
univariate_numerical_analysis(df_analysis.text_length, "text_length Data")
# Out:
# Mean value is 22.63 with 50% of data lying between 11.0 and 29.0
# There are 35133 outliers. 0 outliers are on lower side and 35133 outliers are on upper side

# %% [markdown]
# <span style="font-size:15px; font-family:Arial;color:#e610ad;">
# <li>On average, a summary is 22 characters long
# <li>50% of summary are between 11 and 29 characters
# <li>96% of summaries are below 56 characters
# <li>There is one summary that is 163 characters long

# %%
univariate_numerical_analysis(df_analysis.word_count, "word_count Data")
# Out:
# Mean value is 4.00 with 50% of data lying between 2.0 and 5.0
# There are 44636 outliers. 0 outliers are on lower side and 44636 outliers are on upper side

# %% [markdown]
# <span style="font-size:15px; font-family:Arial;color:#e610ad;">
# <li>50% of summary are between 2 and 5 words
# <li>95% of summary are below 10 words
# <li>There is one summary that is 43 words long

# %%
df.columns
# Out:
# Index(['reviewerID', 'asin', 'reviewerName', 'helpful', 'reviewText',
#        'overall', 'summary', 'unixReviewTime', 'reviewTime',
#        'helpfulness_ratio', 'total_ratings', 'reviewDate', 'review_age_days',
#        'bookRating'],
#       dtype='object')

# %% [markdown]
# ### unixReviewTime , reviewDate, review_age_days

# %%
df_analysis = df[['reviewDate','review_age_days']].copy()
df_analysis['month'] = df_analysis['reviewDate'].dt.month
df_analysis['weekday'] = df_analysis['reviewDate'].dt.day_name()
df_analysis
# Out:
#        reviewDate  review_age_days  month    weekday
# 0      2013-06-03              415      6     Monday
# 1      2013-10-05              291     10   Saturday
# 2      2013-06-16              402      6     Sunday
# 3      2014-03-25              120      3    Tuesday
# 4      2014-06-28               25      6   Saturday
# ...           ...              ...    ...        ...
# 882614 2014-02-23              150      2     Sunday
# 882615 2012-01-22              913      1     Sunday
# 882616 2013-10-14              282     10     Monday
# 882617 2014-01-08              196      1  Wednesday
# 882618 2013-12-25              210     12  Wednesday
#
# [882619 rows x 4 columns]

# %%
# Basic stats
print(f"First review: {df_analysis['reviewDate'].min()}")
print(f"Last review: {df_analysis['reviewDate'].max()}")
print(f"Date range: {(df_analysis['reviewDate'].max() - df_analysis['reviewDate'].min()).days} days")
# Out:
# First review: 2000-03-05 00:00:00
# Last review: 2014-07-23 00:00:00
# Date range: 5253 days

# %%
# Monthly patterns
monthly_pattern = df_analysis.groupby('month').size()
monthly_pattern.plot(kind='bar', title='Reviews by Month')
# Out:
# <Axes: title={'center': 'Reviews by Month'}, xlabel='month'>

# %% [markdown]
# <span style="font-size:15px; font-family:Arial;color:#e610ad;">
# <li>The first half of year is having more numberof reviews per month, compared to second half.

# %%
# Day of week patterns
weekday_pattern = df_analysis.groupby('weekday').size()
weekday_pattern.plot(kind='bar', title='Reviews by Day of Week')
# Out:
# <Axes: title={'center': 'Reviews by Day of Week'}, xlabel='weekday'>

# %% [markdown]
# <span style="font-size:15px; font-family:Arial;color:#e610ad;">
# <li>The reviews are fairly distributed across all days of week, not much to choose from.

# %%
df.columns
# Out:
# Index(['reviewerID', 'asin', 'reviewerName', 'helpful', 'reviewText',
#        'overall', 'summary', 'unixReviewTime', 'reviewTime',
#        'helpfulness_ratio', 'total_ratings', 'reviewDate', 'review_age_days',
#        'bookRating'],
#       dtype='object')

# %% [markdown]
# ### overall
#
# This is our target column for predictions too.
#
# *	Negative (0 <= score < 3),
# *	Mixed (3 <= score < 4),
# *	Positive (4 <= score <= 5)

# %%
col='overall'
univariate_ordinal_analysis(df[col], f"{col} Data")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_29680\3865485292.py:16: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not pd.api.types.is_categorical_dtype(series):
# 📊 Summary Statistics for overall Data
# ...
# Mode   : 5
# Median : 5
#
# Value Counts (%):
#     Count  Percent
# 1   20662     2.34
# 2   30706     3.48
# 3   86341     9.78
# 4  228131    25.85
# 5  516779    58.55
# Breakup of grades-5 (58.55%), 4 (25.85%), 3 (9.78%), 2 (3.48%), 1 (2.34%)

# %%
100-(25.85+58.55+9.8)
# Out:
# 5.799999999999997

# %% [markdown]
# <span style="font-size:15px; font-family:Arial;color:#e610ad;">
# <li>This confirms our earlier finding that most reviews are positive.  A total of 84.4% of reviews are positive, 9.8% are neutral and 5.8% are negative

# %%
col='emp_length'
univariate_numerical_analysis(df[col], f"{col} Data")
# Out:
# Mean value is 6.30 with 50% of data lying between 3.0 and 11.0

# %% [markdown]
# 73% of personal loans are for debt consolidation

# %% [markdown]
# Lets map back the category to original title column. We create a new column

# %%
# Create a mapping from title to title_category
title_to_category = dict(zip(df_analysis['title'], df_analysis['title_category']))

# Map df.title to the corresponding title_category, fallback to original title if not found
df['title_category'] = df['title'].map(title_to_category).fillna(df['title'])
del title_to_category

# %%
df['title_category'] = df['title_category'].apply(lambda x: 1 if x == 'consolidation' else 0)

# %%
col='title_category'
univariate_ordinal_analysis(df[col], f"{col} Data")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_54544\3865485292.py:16: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not pd.api.types.is_categorical_dtype(series):
# 📊 Summary Statistics for title_category Data
# ...
# Mode   : 1
# Median : 1
#
# Value Counts (%):
#     Count  Percent
# 0  107895    27.24
# 1  288135    72.76
# Breakup of grades-1 (72.76%), 0 (27.24%)

# %% [markdown]
# <span style="font-size:15px; font-family:Arial;color:#e610ad;">
# <li>We have successfully created a binary encoding for title column where we are marking rows with title consolidation as 1 and rest 0
# <li>73% of loans are related to consolidation of debt which is in line with the value we got in purpose (consolidation + credit card was 80%)

# %% [markdown]
# ## 3.2 Bivariate and Trivariate Analysis
#
# Lets see how each feature is effective in predicting loan_status by performing a bivariate and Trivariate EDA

# %% [markdown]
# ### Helper Functions

# %% [markdown]
# #### Reusable helper function for ANOVA/KRUSKAL to compare categorical and numerical columns

# %%
#Reusable function
#It will perform Anova or Kruksal based on input
#It will generate all groups and then perform the specific test.
# log = compact, detailed, compactNoDiagram, detailedNoDiagram

import pingouin as pg
#η² for kruskal, ε² for anova
def interpret_effect(size,metric="anova"):
    if(metric=='anova'):
        metric="ε²"
    else:
        metric="η²"

    if size < 0.01:
        effect = f"yet effect negligible ({metric}={size:.2f})."
    elif size < 0.06:
        effect = f"yet effect small ({metric}={size:.2f})."
    elif size < 0.14:
        effect = f"effect medium ({metric}={size:.2f})."
    else:
        effect = f"effect large ({metric}={size:.2f})."   
    return effect

def perform_anova_kruskal(data,numerical_column,categorical_column, test, log="detailed"):
    # Group data by category and extract numerical values
    groups = [group[numerical_column].values for _, group in data.groupby(categorical_column, observed=True)]
    p_value=0
    li="<li>"
    Ho=Ha=HaDetail=HaDetail=effectDesc=""
    

    if(test=='kruskal'):
        #Null Hypothesis= 
        Ho=f"{li}{categorical_column} and {numerical_column} are independent."
        HoDetail=f"{li} Medians of groups of {numerical_column} based on {categorical_column} are same"
        #Alternate Hypothesis
        Ha=f"{li}{categorical_column} and {numerical_column} are DEPENDENT."
        HaDetail=f"{li} Medians of groups of {numerical_column} based on {categorical_column} are different"

        # Perform Kruskal-Wallis Test
        H, p_value  = stats.kruskal(*groups)

        k = len(groups)
        n = len(data)

        # Effect sizes
        epsilon_squared = (H - k + 1) / (n - k)
        effectDesc = f" {interpret_effect(epsilon_squared,"kruskal")}"

        if(log=="detailed"):
            print(f'Ho = {Ho}')
            print(f'Ha = {Ha}')
            print(f'Kruskal-Wallis Result:{H},{p_value}')
            print(f'Effect Size:{effectDesc}')
                  

    if(test=='anova'):
        #Null Hypothesis= 
        Ho=f"{li}{categorical_column} and {numerical_column} are independent."
        HoDetail=f"{li} Mean of groups of {numerical_column} based on {categorical_column} are same"
        #Alternate Hypothesis
        Ha=f"{li}{categorical_column} and {numerical_column} are DEPENDENT."
        HaDetail=f"{li} Mean of groups of {numerical_column} based on {categorical_column} are different"

        # Perform Anova Test
        #anova_result = stats.f_oneway(*groups)
        # p_value= anova_result.pvalue

        #Using pingouin as this gives eta square value too.
        aov = pg.anova(data=data, dv=numerical_column, between=categorical_column)
        # Extract p-value and eta-squared
        p_value = aov['p-unc'].values[0]
        eta_squared = aov['np2'].values[0]  # np2 is partial eta-squared (same as eta-squared for one-way ANOVA)
        effectDesc = f" {interpret_effect(eta_squared)}"

        
        if(log=="detailed"):
            print(f'Ho = {Ho}')
            print(f'Ha = {Ha}')
            print("ANOVA Result:", p_value)     
            print(f'Effect Size (eta square):{np.round(eta_squared,2)},{effectDesc}')   

    if(p_value<0.05):
        if(log=="detailed"):
            print(f"Reject Null Hypothesis. Alternate Hypothesis '{Ha}{HaDetail}' is True, p-value:{p_value:.2f}.\n{effectDesc}")
            
        else:
            print(f'{Ha}(p:{p_value:.2f}), {effectDesc}')
                 
        
        
    else:
        if(log=="detailed"):
            print(f"Fail to Reject Null Hypothesis. Null Hypothesis '{Ho}{HoDetail}' is True, p-value:{p_value:.2f}")            
        else:
            print(f'{Ho}(p:{p_value:.2f})') 
        
    if(log=="detailed"):
        print()

    if("NoDiagram" not in log):
        # We can also do visualization
        fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(15,5))
        sns.boxplot(data=data, y=numerical_column, x=categorical_column, ax=ax[0])
        ax[0].set_ylabel(numerical_column)
        
        df_analysis = df.groupby(categorical_column, as_index=False)[numerical_column].mean()
        sns.barplot(data=df_analysis, x=categorical_column, y=numerical_column, ax=ax[1])
        ax[1].set_xlabel(categorical_column)
        ax[1].set_ylabel(numerical_column)
        ax[1].set_title(f'Average {numerical_column} by {categorical_column}')

        sns.kdeplot(data=data, x=numerical_column, hue=categorical_column, ax=ax[2])
        ax[2].set_title(f"Kdeplot for {numerical_column} by {categorical_column}")
        plt.show()
        if(log=='detailed'):
            print(df_analysis)

# %% [markdown]
# #### Reusable helper function for chi square test for comparing categorical columns

# %%
from scipy.stats import chi2_contingency
def perform_chi_square_test(df, col1, col2, alpha=0.05,log="detailed"):
    """
    Perform Chi-square test on two categorical columns from a DataFrame
    
    Parameters:
    df: pandas DataFrame
    col1: string, name of first categorical column
    col2: string, name of second categorical column  
    alpha: float, significance level (default 0.05)
    
    Returns:
    dict with test results
    """
    li="<li>"
    # Create contingency table
    contingency_table = pd.crosstab(df[col1], df[col2])

    
    # Perform chi-square test
    Ho=f"{li}{col1} and {col2} are independent."
    Ha=f"{li}{col1} and {col2} are DEPENDENT"
    chi2_stat, p_value, dof, expected = chi2_contingency(contingency_table)

    # Compute effect size (Cramér's V)
    n = contingency_table.sum().sum()
    phi2 = chi2 / n
    r, k = contingency_table.shape
    cramers_v = (phi2 / min(k-1, r-1)) ** 0.5

    # p-value Interpretation
    if p_value < 0.05:
        relation = "Dependent (Significant)"
    else:
        relation = "Independent (Not significant)"


    # Cramer V Effect size Interpretation
    if cramers_v < 0.1:
        effectDesc = f"association is Negligible(CramersV={cramers_v:.2f})"
    elif cramers_v < 0.3:
        effectDesc = f"association is Weak(CramersV={cramers_v:.2f})"
    elif cramers_v < 0.5:
        effectDesc = f"association is Moderate(CramersV={cramers_v:.2f})"
    else:
        effectDesc = f"association is Strong(CramersV={cramers_v:.2f})"
    
    # Results
    results = {
        'chi2_statistic': chi2_stat,
        'p_value': p_value,
        'degrees_of_freedom': dof,
        'expected_frequencies': expected,
        'contingency_table': contingency_table,
        'significant': (p_value < alpha)
    }
    
    # Print results
    if(log=="detailed"):
        print("Contingency Table:")
        print(contingency_table)
        print("\n")    
        print(f"Chi-square Test Results:")
        print(f"Chi-square statistic: {chi2_stat:.4f}")
        print(f"p-value: {p_value:.4f}")
        print(f"Degrees of freedom: {dof}")
        print(f"Significant at α={alpha}: {'Yes' if results['significant'] else 'No'}")
    
    if results['significant']:
        if(log=="detailed"):
            print(f"Reject Null Hypothesis. Alternate Hypothesis '{Ha}' is True, p-value:{results['p_value']}. However, {effectDesc}")
        else:
            print(f'{Ha}(p:{results['p_value']:.2f}), however {effectDesc}')
    else:
        if(log=="detailed"):
            print(f"Fail to Reject Null Hypothesis. Null Hypothesis '{Ho}' is True, p-value:{results['p_value']}")
        else:
              print(f'{Ho}(p:{results['p_value']:.2f})')


    # Create normalized crosstab
    crossNormalized12 = pd.crosstab(df[col1], df[col2], normalize='index') * 100
    crossNormalized21 = pd.crosstab(df[col2], df[col1], normalize='index') * 100

    # Create 1x2 subplot figure
    fig, axes = plt.subplots(1, 2, figsize=(12, 5))

    colors = [
        "salmon", "skyblue",   
        "lightgreen", "gold", "orchid", "coral", "khaki",
        "plum", "turquoise", "lightsteelblue", "tan", "lightpink",
        "mediumseagreen", "wheat", "lightsalmon", "aquamarine",
        "thistle", "palegoldenrod", "powderblue", "peru", "lightcyan",
        "violet", "darkseagreen", "peachpuff", "mistyrose"
    ]
    # determine how many categories you have
    num_categories = len(crossNormalized12.columns)

    # now slice the colors list accordingly
    color_list = colors[:num_categories]
    # --- First Plot: Col2 by Col1 ---
    crossNormalized12.plot(kind='bar', stacked=False, ax=axes[0], color=color_list)
    axes[0].set_title(f"{col2} by {col1}")
    axes[0].set_ylabel(f"Percentage of {col2}")
    axes[0].set_xlabel(col1)
    axes[0].legend(title=col2)
    axes[0].tick_params(axis='x', rotation=0)

    # --- Second Plot: Col1 by Col2 ---
    crossNormalized21.plot(kind='bar', stacked=False, ax=axes[1], color=color_list)
    axes[1].set_title(f"{col1} by {col2}")
    axes[1].set_ylabel(f"Percentage of {col1}")
    axes[1].set_xlabel(col2)
    axes[1].legend(title=col1)
    axes[1].tick_params(axis='x', rotation=0)
    plt.show()

    if(log=="detailed"):
        print("="*50)

# %% [markdown]
# ###  reviewText with overall/sentiment

# %%
def label_sentiment(score):
    if score < 3:
        return 'Negative'
    elif score < 4:
        return 'Mixed'
    else:
        return 'Positive'

df_review['sentiment'] = df_review['overall'].apply(label_sentiment)
sns.kdeplot(data = df_review, x='word_count', hue='sentiment')
# Out:
# <Axes: xlabel='word_count', ylabel='Density'>

# %% [markdown]
# <span style="font-size:15px; font-family:Arial;color:#e610ad;">
# <li>The count of words is not too different for positive, mixed or negative reviews.

# %%
df.columns
# Out:
# Index(['reviewerID', 'asin', 'reviewerName', 'helpful', 'reviewText',
#        'overall', 'summary', 'unixReviewTime', 'reviewTime',
#        'helpfulness_ratio', 'total_ratings', 'reviewDate', 'review_age_days',
#        'bookRating', 'sentiment'],
#       dtype='object')

# %% [markdown]
# ### reviewerID vs sentiment

# %%
reviewer_sentiment = df.groupby(['reviewerID', 'sentiment']).size().unstack(fill_value=0)
reviewer_sentiment
# Out:
# sentiment              Mixed  Negative  Positive
# reviewerID
# A00085083TSCV82430YT4      0         0         5
# A0010876CNE3ILIM9HV0       0         1         5
# A00207583M69Q8KX3BOFQ      0         0         6
# A002359833QJM7OQHCXWY      0         1        11
# A00328401T70RFN4P1IT6      0         0         4
# ...                      ...       ...       ...
# AZZMO52V8WZ68              1         1        32
# AZZN6N74U2PA5              1         0        29
# AZZPTYC0F6FWA              3         4         9
# AZZQRGF0PC6WF              0         0         7
# AZZW5NCOD8IA0              1         1        15
#
# [68223 rows x 3 columns]

# %%
#drop the column total_reviews if it exists, so that code is reentrant
reviewer_sentiment = reviewer_sentiment.drop('total_reviews', axis=1, errors='ignore')
reviewer_sentiment['total_reviews'] = reviewer_sentiment.sum(axis=1)
reviewer_sentiment
# Out:
# sentiment              Mixed  Negative  Positive  total_reviews
# reviewerID
# A00085083TSCV82430YT4      0         0         5              5
# A0010876CNE3ILIM9HV0       0         1         5              6
# A00207583M69Q8KX3BOFQ      0         0         6              6
# A002359833QJM7OQHCXWY      0         1        11             12
# A00328401T70RFN4P1IT6      0         0         4              4
# ...                      ...       ...       ...            ...
# AZZMO52V8WZ68              1         1        32             34
# AZZN6N74U2PA5              1         0        29             30
# AZZPTYC0F6FWA              3         4         9             16
# AZZQRGF0PC6WF              0         0         7              7
# AZZW5NCOD8IA0              1         1        15             17
#
# [68223 rows x 4 columns]

# %%
# Calculate percentage of each sentiment per reviewer
for sentiment in ['Positive', 'Negative', 'Mixed']:
    reviewer_sentiment[f'{sentiment}_pct'] = reviewer_sentiment[sentiment] / reviewer_sentiment['total_reviews'] * 100

# %%
print(reviewer_sentiment['Positive_pct'].value_counts().sort_index())
# Out:
# Positive_pct
# 0.000000        491
# 3.030303          1
# 3.636364          1
# 3.846154          1
# 4.166667          1
#               ...
# 99.647887         1
# 99.686520         1
# 99.726776         1
# 99.763033         1
# 100.000000    30831
# Name: count, Length: 1358, dtype: int64

# %%
print(491*100/reviewer_count)
print(30831*100/reviewer_count)
# Out:
# 0.7196986353575774
# 45.19150433138385

# %% [markdown]
# There is no reviewer who has given only positive reviews.
# Only 0.7% of reviewers have never given a positive review
# 45% of reviewers have only given positive reviews

# %%
print(reviewer_sentiment['Negative_pct'].value_counts().sort_index())
# Out:
# Negative_pct
# 0.000000      46553
# 0.236967          1
# 0.289017          1
# 0.310559          1
# 0.326797          1
#               ...
# 91.666667         1
# 92.307692         2
# 94.545455         1
# 94.736842         1
# 100.000000       82
# Name: count, Length: 857, dtype: int64

# %%
print(46553*100/reviewer_count)
print(82*100/reviewer_count)
# Out:
# 68.23651847617373
# 0.12019406944871965

# %% [markdown]
# 68% of reviewers have never given a negative review
# 0.12% of reviews have only given negative reviews

# %% [markdown]
# ### helpful versus overall

# %%
perform_anova_kruskal(df,"helpfulness_ratio","sentiment", "kruksal", log="detailed")
# Out:
# Reject Null Hypothesis. Alternate Hypothesis '' is True, p-value:0.00.
#   sentiment  helpfulness_ratio
# 0     Mixed           0.284798
# 1  Negative           0.358240
# 2  Positive           0.385317

# %% [markdown]
# Given an equal number of positive and negative reviews, users tend to rate the positive reviews helpful more often than they rate the negative reviews helpful.

# %% [markdown]
# ### helpful versus reviewText

# %%
df_review
# Out:
#                                                reviewText  overall  \
# 0       It is a solid principle that the essence of dr...        2
# 1       I really enjoyed Little White Lies (the first ...        3
# 2       Andrew pens "Bloodbath Ritual", a murder myste...        4
# 3       This book was just as good as the first!  I lo...        5
# 4       This book is an excellent way to teach very yo...        5
# ...                                                   ...      ...
# 882614  When I began this series, I was amazed at the ...        5
# 882615  Eve MacMillan, scientist and woman in love, ha...        5
# 882616  I read a few book by this author some good som...        4
# 882617  If I could give this book a six stars I would....        5
# 882618  I was given an advance copy of this book to re...        5
#
#                                                 summary  helpfulness_ratio  \
# 0                   The author should read  "The Stand"           0.878788
# ...

# %%
sns.scatterplot(data = df_review, x='helpfulness_ratio',y='text_length' , hue='sentiment')
# Out:
# <Axes: xlabel='helpfulness_ratio', ylabel='text_length'>

# %%
df_review.corr(numeric_only=True)
# Out:
#                     overall  helpfulness_ratio  text_length  word_count
# overall            1.000000           0.070433    -0.037795   -0.038860
# helpfulness_ratio  0.070433           1.000000     0.153819    0.152075
# text_length       -0.037795           0.153819     1.000000    0.997733
# word_count        -0.038860           0.152075     0.997733    1.000000

# %% [markdown]
# <li>helpfulness ratio is very weakly positive-correlated (corr coeff is 0.15) with length of the review. It means mostly it doesn’t matter what is the length of the review for users to decide if it’s a helpful review, but it doesn’t harm either.

# %% [markdown]
# # 4.0 Actionable Insights & Recommendations

# %% [markdown]
# ## Summary of Observations
# ![image.png](attachment:image.png)

# %% [markdown]
# Below are the summarized insights derived from correlations and descriptive analysis across major fields.
#
# ---
#
# ### 🧾 Reviewer Insights (`reviewerID`)
# - Total of **68,223 reviewers** contributing reviews.
# - The **most active reviewer** has given **over 1,000 reviews**.
# - **13 reviewers** have written **more than 500 reviews each**.
# - On average, each reviewer has contributed **7 reviews**.
#
# ---
#
# ### 📚 Product Insights (`asin` / Book Rating)
# - Dataset includes **61,934 unique book titles**.
# - On average, each book receives **8 reviews**.
# - **50% of books** have **1–6 reviews**.
# - One popular book (`ASIN = B006GWO5WK`) has **1,012 reviews**.
#
# ---
#
# ### 🤝 Helpfulness Metrics (`helpful`)
# - **54% of reviews (≈ 47,823 of 88,269)** have **no helpfulness rating**.
# - **11% of reviewers (≈ 7,412)** have never received a single helpful vote (helpfulness = 0).
# - **58.6% of reviews** show a helpfulness ratio of zero; only **41.4%** have at least one helpful rating.
# - Among rated reviews, about **31% were found genuinely helpful** by readers.
# - The most‑rated review (`ASIN B006GWO5WK`) received **2,357 helpful votes**.
# - Helpfulness is **weakly correlated with review length** (correlation ≈ 0.15).
#   - Length does not strongly determine whether other users find a review helpful.
#
# ---
#
# ### ✍️ Review Content (`reviewText`)
# - **99.8%** of reviews are in **English**.
# - Only **0.1%** contain HTML tags, 0.1% contain urls.
# - **Average review length:** ~604 characters (~110 words).
# - **Length statistics:**
#   - 50% of reviews: **176–714 characters** long.
#   - 91% of reviews: **< 1,521 characters**.
#   - Longest review: **4,385 words**.
# - The median textual length **does not differ significantly by sentiment label (positive, neutral, negative).**
#
# ---
#
# ### ⭐ Overall Ratings (`overall`)
# - **84.4% of all reviews are positive** (rating ≥ 4).
# - **9.8% are neutral** and **5.8% are negative**.
# - **45% of reviewers** have *only ever given positive* reviews.
# - **0.7%** have *never given a positive* review, while **0.1%** gave *only negative* reviews.
# - **68% of reviewers** have *never written a negative* review.
# - Trend indicates a **positive bias** among users — they tend to give high ratings.
# - Users rate **positive reviews as helpful** more often than negative ones given equal content length.
#
# ---
#
# ### 📝 Summary Field (`summary`)
# - **Average summary length:** 22 characters / 4 words.
# - **50%** of summaries are **11–29 characters** long.
# - **96%** of summaries are **under 66 characters**.
# - Longest summary: **153 characters**.
# - **95%** of summaries are **below 110 words** (brief and concise).
# - Summary length shows **no significant impact** on helpfulness or rating.
#
# ---
#
# ### ⏰ Temporal Insights (`unixReviewTime` / `reviewDate` / `review_age_days`)
# - Review data spans **from 2000‑03‑05 to 2014‑07‑20** (≈ 5,263 days).
# - **Older books ( > 5 years)** have more reviews than newer ones.
# - Peak in reviews observed for **books published around 2011–2014**.
# - **80% of reviews** are posted within the **first 6 months** after a book’s publication.
# - Reviews trend shows a **slightly higher review volume in the first half of each year**.
#
# ---
#
# ## 💡 Recommendations Based on EDA Insights
#
# | Area | Observation | Recommendation |
# |-------|--------------|----------------|
# | **Reviewer Activity** | Small percentage of reviewers contribute most reviews. | <li> **For Business**: Incentivise users to become reviewers.  Engagement is always good.<ul><li>Brownie points, user tags can be considered. <li>Is it easy and hasslefree to write a review? <li>Can it take microphone input so that user can 'speak' their review? <li>Is it possible to send email and reminders to users on their email to share their review?<li>When user logs in next time, is it possible to prompt them to give a review.</ul>  <li> **For Model**: Consider weighting reviews or users to avoid overrepresentation of frequent reviewers. |
# | **Positivity Bias** | Majority reviews are positive (84%) with very few negatives. | <li> **For Business**: To encourage negative reviews, option to post anonymously may be explored <li> **For Model**: Employ **class balancing techniques** (e.g., class weights or resampling) to mitigate bias in training data. |
# | **Helpfulness Ratings** | Over half of reviews lack helpful votes. | <li> **For Business**: One can check the reasons, like<ul><li>How easy it is in the UI to mark a review as helpful/not helpful.<li>How easy it is for users to even locate the review section. Is there as easy direct way to reach it.  Where is the reviews section placed on the page?</ul><li> **For Model**: Consider excluding or down-weighting reviews without feedback when modeling helpfulness prediction. |
# | **Review Length** | Median review length does not correlate strongly with quality or helpfulness. | <li> **For Business**: System designed to store reviews needs to be capable of storing very long reviews.  Typical RDBMS may not support this.  Use of NoSQL databases is the way to go that store json objects<li> **For Model**: Avoid using review length as a primary predictive feature; focus more on linguistic or sentiment-based features. |
# | **Summary Texts** | Summaries are short and consistent across reviews. | <li> **For Model**: Combine summaries with review texts for better context enrichment rather than analyzing alone. |
# | **Temporal Patterns** | Majority of reviews occur early in a book’s life cycle. | <li> **For Business**: Marketing efforts can focus here.<ul><li>New books can be promoted on own website.<li>If a book gets great reviews,same can be highlighted.<li>Targeted marketing can be explored where the book is promoted in channels relevant for the book.</ul><li> **For Model**: Recent reviews could be weighted more to capture current sentiment trends. |
# | **Language Consistency** | Nearly all reviews are in English. | <li> **For Business**: Most readers seem to be English speaking. Marketing campaigns can use this information for regional focussing<li> **For Model**: No language normalization required; focus preprocessing on English NLP techniques. |
#
# ---
#
# ### ✅ EDA Takeaway
#
# The dataset is **heavily skewed toward positive sentiments**, with limited negative samples and sparse helpfulness ratings.
# Future modeling efforts should focus on:
# - **Balancing sentiment classes.**
# - **Handling missing “helpful” values.**
# - **Leveraging both summary and reviewText fields.**
#
# These adjustments help ensure a more robust and unbiased sentiment classification model.

# %% [markdown]
# # 5.0 Building a Machine Learning Model to classify the review

# %% [markdown]
# 🧭 Modeling Thought Process — From Heuristics to Deep Learning
#
# ## 1️⃣ Understanding the NLP Landscape
#
# Natural‑Language Processing (NLP) models can be broadly categorized into three generations:
#
# | Category | Concept | Examples |
# |-----------|----------|-----------|
# | **Heuristic / Statistical models** | Text represented using simple counting or frequency rules. Words are treated as independent features. | Bag‑of‑Words (BoW), TF‑IDF, n‑grams |
# | **Classical Machine Learning models** | Combine numerical text features with a linear or tree‑based classifier. | TF‑IDF + SVM / Logistic Regression, HashingVectorizer + SGD |
# | **Deep Learning / Transformer models** | Use pre‑trained embeddings that capture semantic relationships between words and context. | BERT, DistilBERT, RoBERTa, etc. |
#
# We explored these options progressively — from simpler, computationally efficient baselines to more complex, resource‑intensive architectures.
#
# ---
#
# ## 2️⃣ Step 1 — TF‑IDF + Linear Model (Baseline)
#
# TF‑IDF converts text into a sparse matrix of word importance scores across documents.
#
# ### Why TF‑IDF first
# - Classic and interpretive baseline for most text classification tasks.
# - Easy to implement and tune.
#
# ### What happened
# - Our dataset contained **~882 k reviews**.
# - TF‑IDF vocabulary size exploded into the millions of features (especially with bigrams).
# - The resulting matrix couldn’t fit into memory → **out‑of‑memory (RAM) error.**
#
# ### Conclusion
# TF‑IDF is ideal for small or moderate datasets, but it **didn’t scale** to our 800 k+ reviews.
#
# ---
#
# ## 3️⃣ Step 2 — HashingVectorizer + SGDClassifier (Scalable Classical ML)
#
# To overcome TF‑IDF’s scalability issue, we adopted **HashingVectorizer**, a constant‑memory alternative.
#
# ### Why HashingVectorizer
# - No vocabulary storage → fixed, small memory footprint.
# - Easily scales to millions of documents.
# - Supports **streaming / online learning** via `partial_fit`.
# - Works efficiently with linear classifiers like `SGDClassifier`.
#
# ### Implementation
# - `HashingVectorizer(n_features=2**15, stop_words='english')`
# - `SGDClassifier(loss='log_loss', class_weight='balanced', n_jobs=-1)`
# - 3‑fold cross‑validation on **all 882 619 records**.
#
# ### Results
#
# | Metric | Value |
# |--------|-------|
# | **Accuracy** | 0.8817 |
# | **F1‑score** | 0.8813 |
# | **Precision** | 0.8816 |
# | **Recall** | 0.8817 |
#
# ### Outcome
# - Scaled painlessly to the full dataset.
# - Excellent accuracy for a lightweight model.
# - Memory < 2 GB, training < 130 seconds (with a only once 1-hour run to tune hyper parameters)
# - Ideal for CPU‑based deployment.
#
# ---
#
# ## 4️⃣ Step 3 — Deep Learning with BERT
#
# Next, we tested a **Transformers‑based** model (DistilBERT) for potential accuracy gains.
#
# ### Why BERT
# - Captures the *context* and meaning of words beyond simple token frequencies.
# - Proven state‑of‑the‑art on many NLP tasks.
#
# ### Constraints
# - Training full BERT on 882 k records is GPU‑intensive.
# - We trained it on a **subset of 9,000 reviews** for comparison.
#
# ### Results (9 k subset)
#
# | Metric | Value |
# |--------|-------|
# | **Accuracy** | 0.8931 |
# | **F1‑score** | 0.8852 |
# | **Precision** | 0.8809 |
# | **Recall** | 0.8931 |
#
# ### Observations
# - BERT yielded **similar metrics** to HashingVectorizer + SGD (≈ +0.01 accuracy).
# - Substantially slower (minutes per epoch) and GPU‑dependent.
# - Scaling to full 882 k records would be computationally expensive for marginal gains.
#
# ### Conclusion
# While BERT captures deeper linguistic context, **the performance gain (~1 %) didn’t justify the massive training and inference cost** for this task.
#
# ---
#
# ## 5️⃣ Comparative Summary
#
# | Aspect | TF‑IDF + Linear SVM | HashingVectorizer + SGD | BERT (DistilBERT) |
# |--------|--------------------|-------------------------|-------------------|
# | **Data used** | 882 k | 882 k | 9 k subset |
# | **Train time** | ❌ OOM error | ✅ Scalable (~minutes) | ⚠️ Slow (> hours for full set) |
# | **Memory use** | High (vocabulary) | Constant | Very high (GPU) |
# | **Accuracy (CV)** | — | 0.8817 | 0.8931 |
# | **Interpretability** | High | High | Low (black box) |
# | **Deployment ease** | ✅ Excellent | ✅ Excellent | ⚠️ Complex / GPU needed |
#
# ---
#
# ## 6️⃣ Final Decision
#
# Given that both models achieved **≈ 88 – 89 % accuracy**, the marginal 1 % gain with BERT was outweighed by its computational and operational overhead.
#
# ### ✅ Selected Model
# **HashingVectorizer + SGDClassifier**
#
# **Reasons:**
# - Scales to full dataset easily
# - Lightweight and fast inference (CPU‑friendly)
# - Competitively accurate
# - Simple to retrain or update incrementally
#
# ---
#
# ## 7️⃣ Key Takeaways
#
# - Always begin with **simple baselines** (BoW, TF‑IDF) before moving to deep models.
# - When scaling becomes an issue, **HashingVectorizer + SGD** is a robust, production‑ready choice.
# - **Transformers (BERT)** offer semantic understanding, but their cost‑to‑benefit ratio on large, labeled review data is often poor unless extremely high accuracy is required.
# - Classical ML still competes very strongly when ample data are available.
#
# ---
#
# ## 8️⃣ Future Improvements
#
# | Area | Possible Enhancement | Rationale |
# |-------|---------------------|------------|
# | **Model Ensembling** | Combine HashingVectorizer+SGD with another shallow model or averaged BERT predictions. | Often improves accuracy by 1–2 points while remaining interpretable. |
# | **Feature Enrichment** | Incorporate sentiment lexicons, part‑of‑speech counts, or review length as extra numeric features. | Adds complementary signals beyond text content. |
# | **Fine‑Tuning BERT on full data** | Use DistilBERT or TinyBERT and fine‑tune selectively (frozen layers + small LR). | Might close the remaining 1–2 % gap without full training cost. |
# | **Language / Spelling Normalization** | Apply lemmatization or subword normalization if vocabulary noise increases. | Reduces sparsity, decent win on smaller sub‑domains. |
# | **Hybrid Representations** | Combine TF‑IDF or hashed features with dense embeddings (via PCA or averaged BERT vectors). | Balances interpretability and deep semantics. |
# | **Model Monitoring & Drift Detection** | Continuous accuracy tracking as new reviews arrive. | Ensures long‑term model health in production. |
#
# ---
#
# ### 🏁 Summary
#
# > Our modeling path evolved from **heuristic word‑count baselines → scalable linear ML models → deep contextual transformers**.
# > The **HashingVectorizer + SGDClassifier** combination delivered the optimal trade‑off between **accuracy (~88 %)**, **scalability**, and **computational efficiency**.
# > Future efforts can focus on hybridization or incremental BERT fine‑tuning if higher accuracy or richer semantics become necessary.
#
# ---
